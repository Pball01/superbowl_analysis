# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
from datetime import datetime
from datetime import timedelta
import glob
import os
import numpy
import matplotlib.pyplot as plt
import re
import seaborn as sns
import spacy
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':75})
plt.rcParams["figure.autolayout"] = True

# %matplotlib inline

# %%
companies = ["T-Mobile",
                "sprint",
                "Tide",
                "weather tech",
                "turbotax",
                "wix",
                "squarespace",
                "amazon alexa",
                "uber eats"
                ]
"""
companies = ["T-Mobile",
                "sprint",
                "Tide",
                "weather tech",
                "turbotax",
                "wix",
                "squarespace",
                "amazon alexa",
                "uber eats",
                'Budweiser',
                'Budlight',
                'Mars',
                'Jeep',
                'Toyota', 
                'Doritos',
                'Avocado from Mexico',
                'pringles',
                'Pepsi', 
                'Coca-Cola'
                ]
"""
# Out:
# '\ncompanies = ["T-Mobile",\n                "sprint",\n                "Tide",\n                "weather tech",\n                "turbotax",\n                "wix",\n                "squarespace",\n                "amazon alexa",\n                "uber eats",\n                \'Budweiser\',\n                \'Budlight\',\n                \'Mars\',\n                \'Jeep\',\n                \'Toyota\', \n                \'Doritos\',\n                \'Avocado from Mexico\',\n                \'pringles\',\n                \'Pepsi\', \n                \'Coca-Cola\'\n                ]\n'

# %%
print(companies)
# Out:
# ['T-Mobile', 'sprint', 'Tide', 'weather tech', 'turbotax', 'wix', 'squarespace', 'amazon alexa', 'uber eats']

# %%
filenames_before = sorted(glob.glob(f'data/before/*{company}.csv') for company in companies)
filenames_after = sorted(glob.glob(f'data/after/*{company}.csv') for company in companies)
filenames_after_superbowl = sorted(glob.glob(f'data/after/superbowl/*{company}.csv') for company in companies) #contains brand and superbowl in tweets in the text

# %%
def prep_concat(filenames):
    for files in filenames:
        for file in files:
            df = pd.read_csv(file, lineterminator='\n')
            directory = file.partition("/")[2].partition("/")[0]
            company_name = file.partition("_")[2].partition(".")[0]
            df['Company_Name'] = company_name
            df['Directory'] = directory
            df = df.reset_index(drop=True)
            yield df

# %%
before_df = pd.concat((prep_concat(filenames_before))).reset_index(drop=True)
after_df = pd.concat((prep_concat(filenames_after))).reset_index(drop=True)
after_superbowl_df = pd.concat((prep_concat(filenames_after_superbowl))).reset_index(drop=True)

# %%
before_df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/Blkgy/status/5616742195837...
# 1  https://twitter.com/iLostMySanity/status/56167...
# 2  https://twitter.com/abacor/status/561673687431...
# 3  https://twitter.com/Well_Damn_Jesse/status/561...
# 4  https://twitter.com/abacor/status/561673539720...
#
#                     Datetime            Tweet Id  \
# 0  2015-01-31 23:55:44+00:00  561674219583705088
# 1  2015-01-31 23:55:11+00:00  561674081477877760
# 2  2015-01-31 23:53:37+00:00  561673687431008256
# 3  2015-01-31 23:53:21+00:00  561673621056548864
# 4  2015-01-31 23:53:01+00:00  561673539720204289
#
#                                                 Text  Retweet Count  \
# 0  Gospel "@Well_Damn_Jesse: Remember when turnin...              1
# 1  RT @Well_Damn_Jesse: Remember when turnin up  ...              1
# 2  @DocMellyMel @sprint @sprintcare Sprint should...              1
# 3  Remember when turnin up  Drinkin is a marathon...              3
# 4  @DocMellyMel @sprint @sprintcare I filed a com...              2
#
#    Reply Count  Like Count         Username        Display Name  \
# 0            0           0            Blkgy       PanderExpress
# 1            0           0    iLostMySanity      titty swindler
# 2            0           2           abacor         Last Resort
# 3            0           0  Well_Damn_Jesse  Mike from Michigan
# 4            0           1           abacor         Last Resort
#
#    Followers Count  Friends Count  \
# 0              457            223
# 1             3737            658
# 2              465            653
# 3             2444            437
# 4              465            653
#
#                                     Rendered Content  Day  Month  Year  \
# 0  Gospel "@Well_Damn_Jesse: Remember when turnin...   31      1  2015
# 1  RT @Well_Damn_Jesse: Remember when turnin up\n...   31      1  2015
# 2  @DocMellyMel @sprint @sprintcare Sprint should...   31      1  2015
# 3  Remember when turnin up\n\nDrinkin is a marath...   31      1  2015
# 4  @DocMellyMel @sprint @sprintcare I filed a com...   31      1  2015
#
#   Company_Name Directory
# 0       sprint    before
# 1       sprint    before
# 2       sprint    before
# 3       sprint    before
# 4       sprint    before

# %%
before_df['Company_Name'].unique()
# Out:
# array(['sprint', 'T-Mobile', 'weather tech', 'Tide', 'squarespace',
#        'turbotax', 'wix', 'amazon alexa', 'uber eats'], dtype=object)

# %%
nlp = spacy.load('en_core_web_lg')

# %%
text = before_df[before_df["Company_Name"].isin(["sprint"])]['Text'].to_list()[10:20]


docs = [nlp(line) for line in text]

for doc in docs:
    print([(ent.text, ent.label_) for ent in doc.ents]) #using spacy might be a good way to detect company names but it is still not showing up. We would have to train models in order for this to work well.
# Out:
# [('evening', 'TIME'), ('#', 'CARDINAL')]
# [('hld w @sprintcare', 'ORG'), ('4', 'CARDINAL'), ('@sprint', 'ORG'), ('fraud &amp', 'ORG')]
# []
# [('@MasterFutbolUPO  http://t.co/NECvkyxLXY http://t.co/LECaUUYqZk', 'PERSON')]
# [('@sprint_mgmt: BREAKING:', 'WORK_OF_ART'), ('Canadian', 'NORP'), ('6.51', 'CARDINAL'), ('60', 'CARDINAL')]
# [('RevolutionPix', 'ORG')]
# [('@JLeRoy01 Sprint', 'ORG'), ('#$100Credit', 'MONEY')]
# [('4', 'CARDINAL'), ('Keirin Final Glasgow', 'ORG'), ('2nd', 'ORDINAL')]
# [('rey', 'PERSON')]
# [('Bergen', 'ORG')]

# %%
before_df[before_df["Company_Name"].isin(["T-Mobile"])]['Text'].to_list()[40:50] # as the word doesnt overlap with anything else, it is easier to work with.
# There are tweets with both sprint and t-mobile and sprint is bought by t-mobile in 2020
# Out:
# ['Worst of the Week: Have @Verizon, @ATT, @Sprint and @TMobile reached network nirvana? https://t.co/7KJjc8IOz2 https://t.co/8JAWIKR7HF',
#  'Switch to @Sprint &amp; save 50% off most @Verizon, @ATT &amp; @Tmobile rates.  RT if you want a #Denver WIN! #SuperBold50 https://t.co/OOsrIBWk32',
#  'Super Bowl Weekend, Super Bowl Savings! @sprint iPhone 5s for only $12.50/mo. Paired with your #50percentoff plan, #bestdealever    @TMobile',
#  "T-Mobile's Binge On's video speed throttling leads to people opening Netflix slightly less, but watching  it longer. https://t.co/2WpqYyXMZm",
#  'T-Mobile revives ‘Get a Tablet on Us’ promo, offers discounts on other devices as well https://t.co/rTQ0QNjHzB',
#  'Switch to @Sprint &amp; save 50% off most @Verizon, @ATT &amp; @Tmobile rates! RT if you want a #Carolina WIN! #SuperBold50 https://t.co/WO0kP3zOoq',
#  'T-mobile has the worst service☹️',
#  'Who Selling A iPhone 6 With T-Mobile?  Hit My Dms.',
#  'Free roses today with new service! Stop by  T-Mobile Orange to pick up your free tablet! #NErules @TMobileAtWork https://t.co/CufWNd8LVh',
#  "Got a family full of heavy data users? T-Mobile's discounted unlimited plan is for you https://t.co/rV1zMK2lhV https://t.co/vE4ENwcNCq"]

# %%
before_df[before_df["Company_Name"].isin(["sprint"])]['Text'].to_list()[10:20] #sprint used a verb, use nltk to filter for proper nouns
# Out:
# ["Great evening racing in the sprint at revs, didn't ride as well as I'd have liked but was a great experience #revolutionseries",
#  'Bn on hld w @sprintcare 4 almost an hr. Convinced that @sprint has a co. policy of fraud &amp; inconveniencing customers. #SprintSucks',
#  "I wish our data was unlimited but I just can't settle for sprint or T-Mobile garbage asses!",
#  '#Football | Benefits of plyometric &amp; sprint trg in adolescent soccer players @MasterFutbolUPO  http://t.co/NECvkyxLXY http://t.co/LECaUUYqZk',
#  '"@sprint_mgmt: BREAKING: Canadian Akeem Haynes runs 6.51 for 60m. A new world lead in the event! http://t.co/cBaM9AhiNl" @CorykSandC',
#  'Mad sprint and track stand action right in front of me on the back straight! #RevolutionPix @RevolutionUK http://t.co/gjwwi4ucrU',
#  '@JLeRoy01 Sprint at it again... Giving them the best deal to switch/add a line of service! #$100Credit http://t.co/s3dnLnj74P',
#  '@relolutionseries 4 Keirin Final Glasgow @jack_carlin97 great sprint to be placed 2nd http://t.co/HnDxLoYbBR',
#  '@Loveee_Indiaaa cooling rey go to sprint',
#  'The "presentations/workshop" from the Bergen sprint orienteering camp are worth a look http://t.co/PFL1JjGJ3v']

# %%
after_df[after_df["Company_Name"].isin(["sprint"])]['Text'].to_list()[10:20]
# Out:
# ['"@FoolieHypster: If someone says \'I didn\'t see your text\' they absolutely saw your text." If they got @sprint  they dead ass',
#  'RadioShack may sell half its stores to Sprint, shut down the rest #technology http://t.co/jATyULyRgo http://t.co/EJB1qG2tu2',
#  '@BamaStephen see the original full clip of #Eddie the #Sprint #Donkey http://t.co/iJNx4deL4l',
#  '.@RadioShack may close, @sprint would get half of chain http://t.co/YfMUQ8hexi http://t.co/BaPeshQU3t',
#  'RadioShack may sell half its stores to Sprint, shut down the rest #technology http://t.co/XQwoeglU4L http://t.co/k3kJMnnCjj',
#  'RadioShack may sell half its stores to Sprint, shut down the rest #technology http://t.co/Qa1WApNLLt http://t.co/xBry4XwDyQ',
#  'Sprint service suck so hard ..',
#  'Report: Sprint in talks to buy RadioShack stores http://t.co/TnhVqM8Meq',
#  '#NASCAR … 3 teams not running Sprint Unlimited. Here’s what 1 owner said why they’re skipping it: http://t.co/PU4QSK01HC @NASCARonNBC',
#  'I SWEAR I HATE SPRINT THESE BITCHES GETTING OVER 😡😡😡😡😡']

# %%
before_df[before_df["Company_Name"].isin(["Tide"])]['Text'].to_list()[40:50] #cannot find tide in most of the text
# Out:
# ['Low tide at Nauset Light Beach. https://t.co/vM0pR18LYK https://t.co/CayBQZLBNx',
#  'How the tides begin to turn. https://t.co/W0WiiR3G65',
#  "@ericgarland Kent State murders: final straw that turned the tide of public opinion against the VN War. Protests didn't stop; the War did.",
#  "It's here!  TIDES prequel, FIRST COMMAND is now live... and you can get it free at Instafreebie here... https://t.co/lGSnTFMUHG",
#  '@VictorEriceira * #BREXIT &amp; #Trump is a rolling tide of people hungry for their identity back. It is a righteous goal. Pray.',
#  'Thrid #commission for the great @Gazukull, his OC the beautiful Ariella, from Dead Tide series. #fantasy #mermaid #digitalart #illustration https://t.co/qxylGpHEEf',
#  'GIRLS: SHERMAN TIDE 65, TYGARTS VALLEY BULLDOGS 42 (WVHIT). More final scores: https://t.co/h8yMyFuPjr',
#  '"Just like moons and like suns, With the certainty of tides, Just like hopes springing high, Still I’ll rise." - Angelou',
#  'RNLI save dog walker cut off by rising tide on Wirral beach https://t.co/jIAMZtXxaM',
#  '"God bless the morning tide that washes away the sins of the night before" US https://t.co/6ZmE2wUeeS UK https://t.co/YGU0gGl9JV #RT']

# %%
after_df[after_df["Company_Name"].isin(["Tide"])]['Text'].to_list()[40:50]#same issue
# Out:
# ['@faltskog5450 @Godfather19811 going to be interesting when masses are hit personally and tide of opinion changes... what then?!?',
#  'Of course Farage admires Putin. Putin via Assad created this flood tide of human suffering that Farage used for publicity. #Remain #Brexit https://t.co/IcQeMu8Iwu',
#  "#Farage The tide is turning that grinning glaiket snake face is due some #BadKarma and it's coming .#Hasbeens #Farageinthegarage  &amp; #Nuttall https://t.co/0WGaWZbV0R",
#  'Can France stem the populist tide that is conquering Europe — And brought Donald Trump? (via @Pocket) https://t.co/cN69yuGafc',
#  "So you don't want Sabrina to open for The Vamps because she is a girl and you only care about good looking bands like The Tide? Smh.",
#  '@jfgroves @ArutzSheva_En    BLM, IdleNoMore, LeadNow now where does their funding come from?  Tides?Soros?  Follow the $ people!  Anarchists',
#  '@OffsideTrust @steven_walters4 the tide is turning, thanks to @OffsideTrust - no rest until ALL clubs sign up.',
#  'Turning the Tide Against Cholera https://t.co/ObPtIs2wxl',
#  'With moods like tides   #PBBPADALUCKKISSYONG',
#  'I can\'t eat something to "tide me over" if I start eating I won\'t stop till I hate myself']

# %%
before_df[before_df["Company_Name"].isin(["weather tech"])]['Text'].to_list()[40:50] # some time the word is used in seperate places
# Out:
# ['Did you hear? WeatherTech is sneaking into the Big Game this year! Catch the action on 2.13.22. #WeatherTech #FitCrew #BigGame https://t.co/SQhVs1CTNa',
#  "The Mustang is coming off the disabled list today, in about one hours time. I truly hope this is the last of the minor problems for a while. Plus, I got Weather Tech mats for my birthday made specifically for the car. I can't wait to see how they look",
#  'My 70+ old mum has always been tech-averse (she still uses a flip phone) so you can imagine how impressed I am that she has learned how to use Google Assistant (on a Nest Hub Max) for enquiries like the weather and to pull up Daily Mass YouTube or cooking channels on the TV…',
#  'Quantum tech in space? Our remote system can monitor and control the environmental factors in our #quantum labs which can be used for inaccessible and unpredictable environments such as space, underground and unstable weather conditions.  https://t.co/9MbyovnGd4  @PhysicsAtSussex',
#  'For February 11, the Allegan Tech Center, Hillside Main Campus and Young Adult Campus will be closed due to weather conditions.',
#  "@Phillip26185894 @SarahAN09228377 @malakkinslayer @JonathanKines It's been bothering me, I want to blame winter on weather-tech to put gravity on us.   https://t.co/WWAvD7tlhu",
#  '@MadelonVos__ @LynAldenContact In my opinion, certainly Texas 🤠 - history of pro property rights &amp; entrepreneurialism  - dynamic + long history of fast growth - plenty of diversity, also politically - great weather most of the year - energy &amp; land abundance - tech talent, startups - BBQ!',
#  'How Better Weather Tech Can Provide Safeguards Against Climate Change    https://t.co/2cL0PChPnq  @Shimonelkabetz2 #ClimateCrisis #WeatherTech #WeatherForecasting #Weather #ExtremeWeather #ClimateTech #Forecasting',
#  'Tech news  Microsoft brings new Weather button to Insiders in the Beta and Release Preview channel on Windows 11 - Windows Central  Nintendo Switch Sports will be the spiritual successor to the fan-favorite Wii Sports.',
#  '@WeatherTech If you support the unpatriotic NFL, me &amp; my family cannot support you!!']

# %%
after_df[after_df["Company_Name"].isin(["weather tech"])]['Text'].to_list()[40:50]#more weather tech comes up after superbowl maybe
# Out:
# ['8/ @WeatherTech (MacNeil Auto) makes auto floor mats &amp; accessories. 2014 revenue of $450M https://t.co/pvbp44DHWs https://t.co/X5TJWndnYr',
#  'Proud of a product I support 🇺🇸 #madeintheUSA @WeatherTech @SuperBowl',
#  'Cool to see the @WeatherTech Super Bowl ad. American made and the title sponsor of @IMSA racing.',
#  '@CharlaLDraper Glad to hear it Charla! Thank you!',
#  'Great ad, @WeatherTech. Diversity, excellence, and pride on display by workers making automotive products. 👍#MediaWeLike #SB50',
#  '@Pinnacle_Ad @WeatherTech how could I not?! Thanks for a great ad.',
#  'Bravo @WeatherTech - thanks for giving our fellow Americans a chance at the dream 🇺🇸🙌🏽',
#  "@BenCachiaras maybe you can buy #weathertech mats for the #acura so you don't make a mess eating #Doritos while using#razors",
#  "There ya' go @USAlovelist : @WeatherTech for the #SuperBowl ad win with the #madeinAerica theme. Can't go wrong with that!",
#  '@WeatherTech used skillful cinematography to praise American workers. Good call. #adbowl']

# %%
before_df[before_df["Company_Name"].isin(["turbotax"])]['Text'].to_list()[40:50]
# Out:
# ['On behalf of @TurboTax &amp; @DiMeMedia – Thank you so much for joining us tonight! ¡Buenas noches! And happy tax season! #ConTurboTaxPuedes #Ad',
#  'Follow TurboTax on Facebook for all the latest news and tips: https://t.co/GiFjrYlVQd #ConTurboTaxPuedes #Ad',
#  "Many awesome thank you's for everything @turbotax! #ConTurboTaxPuedes https://t.co/Bv6JiyqSib",
#  'On behalf of @TurboTax &amp; @DiMeMedia  – Thank you so much for joining us tonight! ¡Buenas noches! happy tax season! #ConTurboTaxPuedes #Ad',
#  '@latinomarketing @turbotax cheers to tax season #ConTurboTaxPuedes https://t.co/hewSmKo41s',
#  'Follow TurboTax on Facebook for all the latest news and tips: https://t.co/FccnAfYRMH #ConTurboTaxPuedes #Ad',
#  '@latinomarketing @turbotax @MarinesDuarte @GabyNatale @paulabendfeldt @AndreaMinski @gusjournalist thanks everyone! #ConTurboTaxPuedes',
#  'Follow @TurboTax on Twitter and Instagram to get the scoop on how to make the most of tax season! #ConTurboTaxPuedes #Ad',
#  'Follow TurboTax on Facebook for all the latest news and tips: https://t.co/aD0jrnlBye #ConTurboTaxPuedes #Ad',
#  'Follow @TurboTax on Twitter and Instagram to get the scoop on how to make the most of tax season! #ConTurboTaxPuedes #Ad']

# %%
before_df[before_df["Company_Name"].isin(["wix"])]['Text'].to_list()[40:50]
# Out:
# ['@YouTube Oops @Wix I tots gave y’all a shout out and forgot to mention it!',
#  "@ugetmade Good thing, indeed! If there's anything we can do to help, contact our team at @WixHelp",
#  'No second swims in the 100 free, but SB times earned from Wix and Cannon! #sprinters #hardworkpays',
#  '200 IM will see Jones swim in the Championship Final and Campbell swimming Consolation Final. Both swims SB Times, along with Wix! #threeforthree #aquahawks',
#  '@___wix___ @itsmehaven Good morning popster! Please help us spread our official hashtags. Thank you!  #SarahGThis15Me #GoldenPantherAwards_SarahGeronimo',
#  'Behind the Scenes of @Wix #SuperBowlAd | WATCH HERE &gt;&gt; http://t.co/1cRL6R080a  &lt;&lt; #ItsThatEasy @SBC2015',
#  'My very own website! Created by me - made with @Wix http://t.co/Ez3C2w3RI9 #MyProWebsite #ItsThatEasy',
#  'Heads up @mvp86hinesward: when you or anyone else says the word “Easy” during #SB49 everyone in America can win $$$ http://t.co/QwNQiCW1ky',
#  'Heads up @TafoyaNBCSports: when you or anyone else says the word “Easy” during #SB49 everyone in America can win $$$ http://t.co/QwNQiCW1ky',
#  'Heads up @dpshow: whenever you or anyone else says the word “Easy” during #SB49 everyone in America can win $$$ http://t.co/QwNQiCW1ky']

# %%
before_df[before_df["Company_Name"].isin(["squarespace"])]['Text'].to_list()[40:50]
# Out:
# ['Thanks! misterryanboyd：@archmotorcycle and @squarespace teamed up for a super bowl commercial... pretty pumped to see our work displayed on such a large scale. #superbowllii #ArchMotorcycle #KeanuReeves #GardHollinger  https://t.co/cDqA4Vz2tb https://t.co/hA9UWJjewO',
#  '@Fusion87 @Foursquare @squarespace Thank you, you’re right.😳',
#  'But on a serious note @squarespace will we ever get a template that has author profiles and a related post section that showcases blogs in a list format instead of a grid format? That would be my perfect template! @SquarespaceHelp',
#  'misterryanboyd shared on instagram. #Archmotorcycle and @squarespace teamed up for a #superbowlcommercials #KRGT1 https://t.co/IhsKwR1iFV https://t.co/1K0bqXN6t3',
#  "Thx! Arch Motorcycle This  Sunday Arch / Squarespace will be part of the many amazing commercials  to be shown at this year's Super Bowl. Have a look around to see the  videos. https://t.co/PEffGkpnLF #ArchMotorcycle #PerfmanceCruiser Enjoy.  https://t.co/KICBFXWcu5 #KeanuReeves https://t.co/z7QSjSOQmO",
#  "Did not realize until tonight that the Knicks' jersey sponsor is Squarespace. I was under the impression Squarespace only sponsored podcasts.",
#  "This #Sunday #Arch / #squarespace will be part of the many amazing commercials to be shown at this year's #SuperBowl. #Archmotorcycle #KeanuReeves  https://t.co/wqCFr2DKHe https://t.co/IV1HXWvTa4",
#  "Two years in the making, we're so proud to announce that Showlio (https://t.co/o0J8JhOrsS) (@showlioapp) is now publicly available.  Turn your Dropbox into a media sharing machine. Its like Squarespace meets Dropbox. Its Free. Try it!",
#  "Finally switched my website from Squarespace to Format and couldn't be more in love. Also launched a new project called With You that explores how feelings of home take hold. Check it out! @useformat https://t.co/nIXIcVk64P",
#  '“Follow your dreams and before you die, make a SquareSpace website”  Jesus, Keanu https://t.co/nifiLDEcRo']

# %%
before_df[before_df["Company_Name"].isin(["amazon alexa"])]['Text'].to_list()[40:50]
# Out:
# ['Do you have an Amazon Alexa device? Make sure you add the Westcountry Pointing skill and then you can ask ‘alexa, what’s in the news’ to get the latest previews, results, reports and betting gossip from @PointingDC #GoPointing https://t.co/ux1KVLmyl7',
#  "Get Amazon's 4K-Ready Fire TV Stick With Alexa Voice Remote For Just $39 Today [Usually $50] https://t.co/4bF1A1Ctvp https://t.co/MpdGHlnbpc",
#  "An 'acoustic fingerprint' should keep Alexa from waking during Amazon's Super Bowl ad https://t.co/mvjjfFffi8 https://t.co/4Cs6VHfQ6V",
#  "I find that the majority of skills for Amazon's Alexa are really poor quality, badly designed or irrelevant. Take this one for example that claims to determine if you are depressed (it actually asks 5 yes/know questions) #DigitalHealth #mentalhealth https://t.co/kFFj1XGeuR",
#  'Here you can learn how to Connect Alexa to Wifi, how to Connect Echo to Wifi, how to Set up Amazon Echo to Wifi and many more things related to Amazon Alexa Visit here  https://t.co/SBTcNgWS3n   #AlexaDownload #EchoSetup #AlexaSetup #EchoDotSetup #connectechotowifi #AlexaApp https://t.co/nAkK7Fv1p2',
#  "@foodie_reviews Morning mate. Sorry bit late. Had breakfast and went back to sleep. Technology has improved and ruined our lives. Bloody smartphones but anything Amazon is great 'Alexa' 😊 #satchatUK",
#  '"You have Alexa, you can forget about privacy"  "Don\'t you know you\'re being listened to by Alexa ALL THE TIME?!"  "Who knows where Alexa is sending all your information"  ... And 15 other such remarks have led to my Amazon Alexa simply lying there... Unplugged and disconnected.',
#  '@CodemotionIT Proud to be a speaker another time! 😃 See you at #CodemotionRome19 where we will see if #Amazon #Alexa will be able to deploy infrastructure on @Azure using @AzureFunctions. ❤️ @CodemotionIT',
#  'Get iRobot’s Alexa-Enabled Roomba 690 For $248 – Amazon Deals https://t.co/oafnVHCIuA',
#  "With 100M devices sold, Alexa has achieved some level of product-market fit, but Amazon is still looking for Alexa's strategic place within its business (Benedict Evans) https://t.co/CndNLbJaoR https://t.co/6pxwwbM7wD"]

# %%
before_df[before_df["Company_Name"].isin(["uber eats"])]['Text'].to_list()[40:50]
# Out:
# ['Uber eats comment ils sont entrain d’me ruiner',
#  'Just order pizza on @UberEats and I found the same delivery person from the latest weekends.  A very kind Indian young guy that comes in a small van with his mother that awaits for him in the back with a big smile.   This broke my heart and I my way to support him is tipping him https://t.co/CmokfoBFAE',
#  'my @Uber account was hacked and only way to talk with @Uber_Support is to login to my account. How does that work when its been hacked and all the info has changed to login to it? WTF!!!! What say you @Uber  @Uber_Support @UberEats',
#  '@damn_toe Ok?! Cus I’m ordering Uber eats or what ever… my motha and sis gone get that damn cheeseburger x2',
#  '@Uber_Support I have been trying for over six weeks to get four dollars it’s some odd change that is owed to me this is ridiculous I have stopped working for Uber eats until this is resolved how can we work not knowing if we’re going to get paid',
#  'Bro I’ve had uber eats meals that come with like 6 sets of forks/knives/spoons  … on a meal for 1… https://t.co/fsWHwRXzOH',
#  'uber eats be saying “you forgot to finish your order” like nah bro i came to my senses 😭😭',
#  '@Uber_Support is this where I complain about missing orders from my Uber Eats order ?',
#  'Ubereats is smoking dicks. For a smoothie? 😒 https://t.co/TLARnunbsx',
#  "@MimaMilano I'll dwnld UberEATS rn"]

# %% [markdown]
# ### Using sentiment analysis

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/priankaball/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()

# %%
before_df['scores'] = before_df['Text'].apply(lambda Text: sid.polarity_scores(Text))

before_df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/Blkgy/status/5616742195837...
# 1  https://twitter.com/iLostMySanity/status/56167...
# 2  https://twitter.com/abacor/status/561673687431...
# 3  https://twitter.com/Well_Damn_Jesse/status/561...
# 4  https://twitter.com/abacor/status/561673539720...
#
#                     Datetime            Tweet Id  \
# 0  2015-01-31 23:55:44+00:00  561674219583705088
# 1  2015-01-31 23:55:11+00:00  561674081477877760
# 2  2015-01-31 23:53:37+00:00  561673687431008256
# 3  2015-01-31 23:53:21+00:00  561673621056548864
# 4  2015-01-31 23:53:01+00:00  561673539720204289
#
#                                                 Text  Retweet Count  \
# 0  Gospel "@Well_Damn_Jesse: Remember when turnin...              1
# 1  RT @Well_Damn_Jesse: Remember when turnin up  ...              1
# 2  @DocMellyMel @sprint @sprintcare Sprint should...              1
# 3  Remember when turnin up  Drinkin is a marathon...              3
# 4  @DocMellyMel @sprint @sprintcare I filed a com...              2
#
#    Reply Count  Like Count         Username        Display Name  \
# 0            0           0            Blkgy       PanderExpress
# 1            0           0    iLostMySanity      titty swindler
# 2            0           2           abacor         Last Resort
# 3            0           0  Well_Damn_Jesse  Mike from Michigan
# 4            0           1           abacor         Last Resort
#
#    Followers Count  Friends Count  \
# 0              457            223
# 1             3737            658
# 2              465            653
# 3             2444            437
# 4              465            653
#
#                                     Rendered Content  Day  Month  Year  \
# 0  Gospel "@Well_Damn_Jesse: Remember when turnin...   31      1  2015
# 1  RT @Well_Damn_Jesse: Remember when turnin up\n...   31      1  2015
# 2  @DocMellyMel @sprint @sprintcare Sprint should...   31      1  2015
# 3  Remember when turnin up\n\nDrinkin is a marath...   31      1  2015
# 4  @DocMellyMel @sprint @sprintcare I filed a com...   31      1  2015
#
#   Company_Name Directory                                             scores
# 0       sprint    before  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1       sprint    before  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2       sprint    before  {'neg': 0.176, 'neu': 0.824, 'pos': 0.0, 'comp...
# 3       sprint    before  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4       sprint    before  {'neg': 0.109, 'neu': 0.891, 'pos': 0.0, 'comp...

# %%
before_df['compound']  = before_df['scores'].apply(lambda score_dict: score_dict['compound'])

before_df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/Blkgy/status/5616742195837...
# 1  https://twitter.com/iLostMySanity/status/56167...
# 2  https://twitter.com/abacor/status/561673687431...
# 3  https://twitter.com/Well_Damn_Jesse/status/561...
# 4  https://twitter.com/abacor/status/561673539720...
#
#                     Datetime            Tweet Id  \
# 0  2015-01-31 23:55:44+00:00  561674219583705088
# 1  2015-01-31 23:55:11+00:00  561674081477877760
# 2  2015-01-31 23:53:37+00:00  561673687431008256
# 3  2015-01-31 23:53:21+00:00  561673621056548864
# 4  2015-01-31 23:53:01+00:00  561673539720204289
#
#                                                 Text  Retweet Count  \
# 0  Gospel "@Well_Damn_Jesse: Remember when turnin...              1
# 1  RT @Well_Damn_Jesse: Remember when turnin up  ...              1
# 2  @DocMellyMel @sprint @sprintcare Sprint should...              1
# 3  Remember when turnin up  Drinkin is a marathon...              3
# 4  @DocMellyMel @sprint @sprintcare I filed a com...              2
#
#    Reply Count  Like Count         Username        Display Name  \
# 0            0           0            Blkgy       PanderExpress
# 1            0           0    iLostMySanity      titty swindler
# 2            0           2           abacor         Last Resort
# 3            0           0  Well_Damn_Jesse  Mike from Michigan
# 4            0           1           abacor         Last Resort
#
#    Followers Count  Friends Count  \
# 0              457            223
# 1             3737            658
# 2              465            653
# 3             2444            437
# 4              465            653
#
#                                     Rendered Content  Day  Month  Year  \
# 0  Gospel "@Well_Damn_Jesse: Remember when turnin...   31      1  2015
# 1  RT @Well_Damn_Jesse: Remember when turnin up\n...   31      1  2015
# 2  @DocMellyMel @sprint @sprintcare Sprint should...   31      1  2015
# 3  Remember when turnin up\n\nDrinkin is a marath...   31      1  2015
# 4  @DocMellyMel @sprint @sprintcare I filed a com...   31      1  2015
#
#   Company_Name Directory                                             scores  \
# 0       sprint    before  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1       sprint    before  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2       sprint    before  {'neg': 0.176, 'neu': 0.824, 'pos': 0.0, 'comp...
# 3       sprint    before  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4       sprint    before  {'neg': 0.109, 'neu': 0.891, 'pos': 0.0, 'comp...
#
#    compound
# 0    0.0000
# 1    0.0000
# 2   -0.4588
# 3    0.0000
# 4   -0.2960

# %%
before_df['comp_score'] = before_df['compound'].apply(lambda c: 'neu' if c ==0 else ('pos' if c>0 else 'neg'))
#before_df['comp_score'] = before_df['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')
before_df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/Blkgy/status/5616742195837...
# 1  https://twitter.com/iLostMySanity/status/56167...
# 2  https://twitter.com/abacor/status/561673687431...
# 3  https://twitter.com/Well_Damn_Jesse/status/561...
# 4  https://twitter.com/abacor/status/561673539720...
#
#                     Datetime            Tweet Id  \
# 0  2015-01-31 23:55:44+00:00  561674219583705088
# 1  2015-01-31 23:55:11+00:00  561674081477877760
# 2  2015-01-31 23:53:37+00:00  561673687431008256
# 3  2015-01-31 23:53:21+00:00  561673621056548864
# 4  2015-01-31 23:53:01+00:00  561673539720204289
#
#                                                 Text  Retweet Count  \
# 0  Gospel "@Well_Damn_Jesse: Remember when turnin...              1
# 1  RT @Well_Damn_Jesse: Remember when turnin up  ...              1
# 2  @DocMellyMel @sprint @sprintcare Sprint should...              1
# 3  Remember when turnin up  Drinkin is a marathon...              3
# 4  @DocMellyMel @sprint @sprintcare I filed a com...              2
#
#    Reply Count  Like Count         Username        Display Name  \
# 0            0           0            Blkgy       PanderExpress
# 1            0           0    iLostMySanity      titty swindler
# 2            0           2           abacor         Last Resort
# 3            0           0  Well_Damn_Jesse  Mike from Michigan
# 4            0           1           abacor         Last Resort
#
#    Followers Count  Friends Count  \
# 0              457            223
# 1             3737            658
# 2              465            653
# 3             2444            437
# 4              465            653
#
#                                     Rendered Content  Day  Month  Year  \
# 0  Gospel "@Well_Damn_Jesse: Remember when turnin...   31      1  2015
# 1  RT @Well_Damn_Jesse: Remember when turnin up\n...   31      1  2015
# 2  @DocMellyMel @sprint @sprintcare Sprint should...   31      1  2015
# 3  Remember when turnin up\n\nDrinkin is a marath...   31      1  2015
# 4  @DocMellyMel @sprint @sprintcare I filed a com...   31      1  2015
#
#   Company_Name Directory                                             scores  \
# 0       sprint    before  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1       sprint    before  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2       sprint    before  {'neg': 0.176, 'neu': 0.824, 'pos': 0.0, 'comp...
# 3       sprint    before  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4       sprint    before  {'neg': 0.109, 'neu': 0.891, 'pos': 0.0, 'comp...
#
#    compound comp_score
# 0    0.0000        neu
# 1    0.0000        neu
# 2   -0.4588        neg
# 3    0.0000        neu
# 4   -0.2960        neg

# %%
after_df['scores'] = after_df['Text'].apply(lambda Text: sid.polarity_scores(Text))
after_df['compound']  = after_df['scores'].apply(lambda score_dict: score_dict['compound'])
#after_df['comp_score'] = after_df['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')
after_df['comp_score'] = after_df['compound'].apply(lambda c: 'neu' if c ==0 else ('pos' if c>0 else 'neg'))

# %%
after_df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/MoreGiftsforLes/status/562...
# 1  https://twitter.com/AlisonWrightNI/status/5623...
# 2  https://twitter.com/sprint_central/status/5623...
# 3  https://twitter.com/josephjett/status/56239632...
# 4  https://twitter.com/LordJerms/status/562395098...
#
#                     Datetime            Tweet Id  \
# 0  2015-02-02 23:57:34+00:00  562399459569438720
# 1  2015-02-02 23:53:05+00:00  562398330115067905
# 2  2015-02-02 23:52:17+00:00  562398129513705472
# 3  2015-02-02 23:45:07+00:00  562396327435571206
# 4  2015-02-02 23:40:14+00:00  562395098064105472
#
#                                                 Text  Retweet Count  \
# 0  Blackberry Style 9670 Smartphone - Sprint http...              1
# 1  @dhtherex see the original full clip of #Eddie...              2
# 2  New paint scheme for Dave Gravel and Roth Moto...              9
# 3  RadioShack may close, Sprint to get half of ch...              3
# 4  I can't wife a bitch that got sprint, that's w...              2
#
#    Reply Count  Like Count         Username         Display Name  \
# 0            0           0  MoreGiftsforLes  More Gifts for Less
# 1            0           1   AlisonWrightNI        Alison Wright
# 2            0          33   sprint_central    Sprintcar Central
# 3            0           1       josephjett          Joseph Jett
# 4            1           0        LordJerms                Jerms
#
#    Followers Count  Friends Count  \
# 0              360            584
# 1               72            153
# 2             4632            713
# 3            85153           9538
# 4             3136            945
#
#                                     Rendered Content  Day  Month  Year  \
# 0  Blackberry Style 9670 Smartphone - Sprint dlvr...    2      2  2015
# 1  @dhtherex see the original full clip of #Eddie...    2      2  2015
# 2  New paint scheme for Dave Gravel and Roth Moto...    2      2  2015
# 3  RadioShack may close, Sprint to get half of ch...    2      2  2015
# 4  I can't wife a bitch that got sprint, that's w...    2      2  2015
#
#   Company_Name Directory                                             scores  \
# 0       sprint     after  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1       sprint     after  {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'comp...
# 2       sprint     after  {'neg': 0.143, 'neu': 0.857, 'pos': 0.0, 'comp...
# 3       sprint     after  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4       sprint     after  {'neg': 0.152, 'neu': 0.718, 'pos': 0.13, 'com...
#
#    compound comp_score
# 0    0.0000        neu
# 1    0.3182        pos
# 2   -0.1280        neg
# 3    0.0000        neu
# 4   -0.1351        neg

# %%
after_superbowl_df['scores'] = after_superbowl_df['Text'].apply(lambda Text: sid.polarity_scores(Text))
after_superbowl_df['compound']  = after_superbowl_df['scores'].apply(lambda score_dict: score_dict['compound'])
#after_superbowl_df['comp_score'] = after_superbowl_df['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')
after_superbowl_df['comp_score'] = after_superbowl_df['compound'].apply(lambda c: 'neu' if c ==0 else ('pos' if c>0 else 'neg'))

# %%
after_superbowl_df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/JennHoffman/status/5623825...
# 1  https://twitter.com/FastCoCreative/status/5622...
# 2  https://twitter.com/USATODAY/status/5622431380...
# 3  https://twitter.com/mcashion03/status/56223077...
# 4  https://twitter.com/WPTV/status/56222708575086...
#
#                     Datetime            Tweet Id  \
# 0  2015-02-02 22:50:34+00:00  562382596684775425
# 1  2015-02-02 14:22:25+00:00  562254718005952512
# 2  2015-02-02 13:36:24+00:00  562243138035933184
# 3  2015-02-02 12:47:17+00:00  562230775765295104
# 4  2015-02-02 12:32:37+00:00  562227085750861824
#
#                                                 Text Retweet Count  \
# 0  Love it RT @CNNMoney: .@Sprint, @TMobile CEOs ...             1
# 1  .@Sprint said sorry for the screaming sheep at...             2
# 2  We laughed, we cried, we got angry: The #Super...            41
# 3  @TMobile @TMobileHelp @sprint Loved the superb...             1
# 4  Sprint, T-Mobile CEOs brawl on #Twitter over #...             1
#
#   Reply Count Like Count        Username         Display Name Followers Count  \
# 0           0          1     JennHoffman         Jenn Hoffman           12218
# 1           0          2  FastCoCreative  Fast Co. Creativity          153456
# 2           4         52        USATODAY            USA TODAY         4731811
# 3           2          0      mcashion03         Mike Cashion            1239
# 4           0          2            WPTV                 WPTV          169185
#
#   Friends Count                                   Rendered Content Day Month  \
# 0          3316  Love it RT @CNNMoney: .@Sprint, @TMobile CEOs ...   2     2
# 1            99  .@Sprint said sorry for the screaming sheep at...   2     2
# 2           914  We laughed, we cried, we got angry: The #Super...   2     2
# 3          1067  @TMobile @TMobileHelp @sprint Loved the superb...   2     2
# 4          1319  Sprint, T-Mobile CEOs brawl on #Twitter over #...   2     2
#
#    Year Company_Name Directory  \
# 0  2015       sprint     after
# 1  2015       sprint     after
# 2  2015       sprint     after
# 3  2015       sprint     after
# 4  2015       sprint     after
#
#                                               scores  compound comp_score
# 0  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'comp...    0.6369        pos
# 1  {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'comp...   -0.4404        neg
# 2  {'neg': 0.282, 'neu': 0.574, 'pos': 0.144, 'co...   -0.4404        neg
# 3  {'neg': 0.096, 'neu': 0.538, 'pos': 0.365, 'co...    0.7906        pos
# 4  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        neu

# %%
before_df.groupby('comp_score')['Text'].count()
# Out:
# comp_score
# neg    1923
# neu    2828
# pos    4978
# Name: Text, dtype: int64

# %%
before_df.groupby('comp_score')['Text'].count()/before_df.shape[0]
# Out:
# comp_score
# neg    0.197656
# neu    0.290677
# pos    0.511666
# Name: Text, dtype: float64

# %%
before_df.groupby(['comp_score', 'Company_Name', 'Year'])['Text'].count().reset_index()
# Out:
#     comp_score  Company_Name  Year  Text
# 0          neg      T-Mobile  2015    61
# 1          neg      T-Mobile  2016    39
# 2          neg      T-Mobile  2017    67
# 3          neg      T-Mobile  2018    39
# 4          neg      T-Mobile  2019    17
# ..         ...           ...   ...   ...
# 99         pos  weather tech  2021    10
# 100        pos  weather tech  2022     9
# 101        pos           wix  2015    47
# 102        pos           wix  2017    29
# 103        pos           wix  2018    31
#
# [104 rows x 4 columns]

# %%
after_df.groupby('comp_score')['Text'].count()
# Out:
# comp_score
# neg    2866
# neu    3943
# pos    8716
# Name: Text, dtype: int64

# %%
after_df.groupby('comp_score')['Text'].count()/after_df.shape[0]
# Out:
# comp_score
# neg    0.184605
# neu    0.253977
# pos    0.561417
# Name: Text, dtype: float64

# %%
after_superbowl_df.groupby('comp_score')['Text'].count()
# Out:
# comp_score
# neg     401
# neu     721
# pos    1405
# Name: Text, dtype: int64

# %%
after_superbowl_df.groupby('comp_score')['Text'].count()/after_superbowl_df.shape[0]
# Out:
# comp_score
# neg    0.158686
# neu    0.285319
# pos    0.555995
# Name: Text, dtype: float64

# %%
before_df[before_df["comp_score"].isin(["pos"])]['Text'].to_list()[:-1]
# Out:
# ['@Sprint_Store601 shaine was so helpful!! My bestie would be lost without him! He fixed her phone👍😊 #twitterlesserin',
#  "Congratulations Katherine Badham and Leo Roper, taking out the Women and Men's Sprint! #triseriesnz @sovereignnz http://t.co/oDI4OyuDc3",
#  "Great evening racing in the sprint at revs, didn't ride as well as I'd have liked but was a great experience #revolutionseries",
#  "I wish our data was unlimited but I just can't settle for sprint or T-Mobile garbage asses!",
#  '#Football | Benefits of plyometric &amp; sprint trg in adolescent soccer players @MasterFutbolUPO  http://t.co/NECvkyxLXY http://t.co/LECaUUYqZk',
#  '@JLeRoy01 Sprint at it again... Giving them the best deal to switch/add a line of service! #$100Credit http://t.co/s3dnLnj74P',
#  '@relolutionseries 4 Keirin Final Glasgow @jack_carlin97 great sprint to be placed 2nd http://t.co/HnDxLoYbBR',
#  'The "presentations/workshop" from the Bergen sprint orienteering camp are worth a look http://t.co/PFL1JjGJ3v',
#  'RT: @fannyanny20: @jmitchell49 &amp; @matcrampton at a tense and exciting sprint stand-off @RevolutionUK  #RevolutionPix http://t.co/MOq0yemCsX',
#  'Next weekend races at Spirit Mountain in Duluth tell your friends and come watch some sprint racing!! #Sprints #CCSA',
#  'Noah 1st place in the 2 mile by 0.01 seconds#sprint to the finish#big win not pr time though... http://t.co/uCwkSP7zlN',
#  "#Otepää #europeanchampionships Men's Sprint: Gold: Slepov (RUS Silver: Birkeland (NOR) Bronze: Guigonnat (FRA) Well done! #biathlon",
#  'Eq Guinea bench keep ball from throw-in, Tubisia bench sprint over and now another shoving match. Amazing scenes, full-time will be crazy',
#  'Congrats to the winners of #ErgSprints LtWt Jr Men 500M Sprint Championship: Grant Herzberg, Brandon Hutchinson, Emmanuel Steiner Robles',
#  "Yes. RT@SJ_Murray: Writing isn't a sprint or even a marathon. It's getting up every day and finding even just a little to nurture passion.",
#  'Congratulations to the winners of #ErgSprints Jr Men 500M Sprint Championship: Christian Tabash, Kevin Garvis, Sean Brown',
#  'Well done to @neilthomsonswim members Jonathan Paxton and Tim Bailey for completing the Chill Swim Lake Windermere sprint today #triathlon',
#  'NEW PAPER. Elite Sprint Acceleration Mechanics. Congrats to friends &amp; coworkers Rabita et al. great team work b#tches http://t.co/L9i1H3gEMb',
#  '@YLMSportScience thanks Lucky Luke :-) Sprint acceleration…Produce Force, Apply and Transfer effectively onto the ground',
#  "How is Knacque 15/1 at Gulfstream? She's faced better fields than this and she proved early in her career than she can sprint.",
#  'BOOM! Little sister takes 1st @ErgSprints in 12 year old 500m sprint! 1:53avg. Not bad for the first try! #MartschMadness #2032Olympics?',
#  'Plyo + sprint training within regular soccer practice improves explosive actions of pubertal soccer players @NSCA http://t.co/kWexxdPclX',
#  "In two days' worth of junior and senior sprint racing, @biathloncanada's Leilani Tam Von Burg racked up the top... http://t.co/ZRMr2L093J",
#  '#Sprint | Improve your ability to produce high HORIZONTAL force for ↗ perf drg the acceleration phase | by @jb_morin http://t.co/6WvbSvZ76u',
#  "@MumsnetTowers Parenting Kids with Special Needs - why there are 7 stages, and it's a marathon not a sprint http://t.co/gm5hswmgkm",
#  'What does it take to have a successful Sprint Planning meeting? http://t.co/YY4niKciAu  #agile #scrum http://t.co/ZXLCr4HYGY',
#  'Showing our support for the @Patriots ! #GoPats #PatsNation #NewEngland #DoYourJob #Boston #Sprint @John_Gore54 #Pats http://t.co/tfQrerVpIb',
#  "Our PPOD, B's Headliner, takes the Naples-Ft Myers Sprint Championship title! http://t.co/Y1Q5ZbdLSf #GreyhoundRacing http://t.co/dAUxRTCXj0",
#  'The Sprint Cup And @KevinHarvick are enjoying their time with @jimmyjohns at #ClusterFest http://t.co/WJpaXeXr9e',
#  'Gave it all I could give at the 10k Classic race this morning..  Happy with my effort. On to the always fun relay!  Long sprint here I come.',
#  '"Every rep we take in the weight room is for the people who buy a ticket to watch us play. Every sprint is for them. We can\'t let them down"',
#  '@MissGovathson We play tomorrow. We will be back to 5th and 1 point behind 4th. Be easy mainini. Its a marathon. Not a sprint!',
#  '@CallumSkinner lines up and comes past @matcrampton to win round two of the sprint. http://t.co/ZcsOtSlw47',
#  'A specific combined plyometric &amp; sprint training improved explosive actions compared to soccer training only. http://t.co/4CYQtt99hY',
#  '2:50 Chelmsford (1st Feb) Expert Sprint Race Analysis From Eric Winner. Read More http://t.co/wtTirE1YcR #racingtips #bettingtips #bets',
#  '2:50 Chelmsford (1st Feb) Expert Sprint Race Analysis From Eric Winner. Read More http://t.co/gZel71fM6b #racingtips #bettingtips #bets',
#  '2:50 Chelmsford (1st Feb) Expert Sprint Race Analysis From Eric Winner. Read More http://t.co/53suekyTRQ #racingtips #bettingtips #bets',
#  'Very Accurate 😂“@yagaltiny: I either got LTE or 1x no in between, thanks sprint :)”',
#  '!Gold today in SWE #Rally sprint! !Job Well Done Pontus and Patrik!  #WRC #RallySM @RALLYSM #smveckan http://t.co/SAsG5v9X9x',
#  'Is NC State a sprint program or what? Anton Ipsen 8:55.70 in the 1000 free: new School Record. #gopack',
#  '...his 2nd win of the season @ScruffyLuke with a 4 lap solo finish, @carl_luke winning the Sprint for 2nd &amp; @Evospangler 6th in the cat2/3',
#  'Windsor boys take the 1,600 sprint medley title at the CCC Championships. Runs 3:47.35 to beat Simsbury by 3 secs #cttrack',
#  'Darion Worlds Technician at Sprint Team Poplar converts on a Tablet that makes Tablet number 7 at team Poplar. http://t.co/y7j5H27xRr',
#  'Looks like Mauer can sprint like a Jaguar - 8.63 in the 55m. Bruce also earned a PR in the 55m @ the 9-10 Grade Champs w/ a 8.64.',
#  'The Bears finish the sweep of the Sprint freestyles! Evelyn won the 100 for the girls and Donny and Trevor went 1-2 in the Boys! #bust-it',
#  'Happy people taking advantage of the iPad bundle here at Sprint #2718 @Carol_Anderson4 @ChappySprint @kgbond0007 http://t.co/Xu9L9Cl4MV',
#  "Ken Ramsey also reports that: BC Turf Sprint winner Bobby's Kitten is on the farm being freshened,to return to Chad Brown arnd April (cont)",
#  "Writing isn't a sprint or even a marathon. It's getting up every day and finding even just a little to nurture passion. #amwriting #author",
#  "This was an unexpected prize for my boy Abel after the sprint on Key Biscayne. Well, don't make a right turn on red. http://t.co/mUXuIDUzYF",
#  'Video: Pauline Ferrand Prevot’s Narrow Sprint Win and Post-Race Interview http://t.co/MgFVaGAehG via @cyclocross',
#  '“@_txill: relationships r not a walk in the park 👫_🌳_🌳🌳🌳☀️  or a sprint💃_💕___🏃💨💨💨  more like 💏🌊🌊🏊🏊🏊🌊🌊🏊🌊 🌊🌊🏊🏊🌊🌊🚴🗻🗻🗻🚴 🚴🗻🗻🚴🚴🏇🏇🏇 🌋🌋🌋🏃🏃🏃🏃🚓🚒🚑” 😂😂😂',
#  'Perfect place for some Sprint Action before my workout #health #sprints #body #workout #gym #weight… http://t.co/K3T4ObrGwY',
#  "Loved hearing everyone's original stories at today's teen writing session. Writing sprint was fun too! Thanks to @WBC_Libraries for hosting.",
#  '@FoodGatherer thank you for your loyal custom xxx',
#  'Our girls missed the break today at Hillingdon with @NReddyCycling winning the sprint in the main bunch for a provisional 7th with Emma 11th',
#  'Rally Sprint Champions!!! Fantastic day with great efforts from the whole team! So happy! #SMveckan #EVENManagement http://t.co/Bwf76fCIvC',
#  "I need to carb load tonight for tomorrow, because it's a marathon not a sprint. I need all the energy I can get. #imperial #SuperBowl",
#  '"We\'re pushing stronger for Inclusivity &amp; Sustainability - it\'s a marathon, not a sprint, we need to work together" @SwiftAlphaOne #HackCon',
#  "@DrifterM184 @sprint nope! Only @TMobile and it's free!",
#  '🎦 #Hearthstone  @SKGaming  Streaming ON!🎦 http://t.co/zgNVRp3Sc5 Last sprint to top 100!',
#  "“@TrillAssMikee: @Bambeno_ceno you a Bundy you look like a nigga that'll have sprint” 😂😂 I do got sprint",
#  'Sprint want all your money😒',
#  "I'm writing a book with @GVDesignTeam about our sprint process. If you like, sign up for email updates here: http://t.co/BTEavJwkge",
#  'Dear @sprint,  We may have to part ways.',
#  'Want to improve your #sprint start? Avoid pushing back hard on #blocks. Instead use them as a support so that u can release ur body quickly.',
#  "We're counting down to the 2/14 #NASCAR Sprint Unlimited Cup race at @DISupdates with 2001 winner @TonyStewart! http://t.co/pKQApqSO1l",
#  '@elliesalthouse make it an awesome day today Salty!! #FIERCE!!! 2015 Kinloch OTU Sprint Triathlon Oceania Championships',
#  'At Pitbull concert with the best boss, Bobbi Lee @blee01 #Sprint #harman #workhard #arizonasuperbowl #pitbull http://t.co/nrK0zZJDGB',
#  'What a day! We finished 2nd overall in Swedish Championship in Rally-Sprint today!! Great Co-driver… http://t.co/zjPqQyP948',
#  'Best #drupal camp food I’ve ever had yesterday at #DrupalCampNJ sprint/training. And cool glass bug with lid camp swag. Yay!',
#  "@sprint  sorry but no thanks, I've had u guys before.. @TMobile has better service and there plans are cheaper ☺ #Loyal 🙅",
#  '.@akisselv .@ChappySprint .@kgbond0007 .@marceloclaure  Are you ready for another #SuperSaturday @ #Sprint #BestValue http://t.co/MAF3MqYa0J',
#  '6x Sprint Cup Champ @JimmieJohnson wants to kick off 2015 w/ you &amp; your child w/ a special #DAYTONA500 tix package! http://t.co/XzvB1W6riJ',
#  '#Chattanooga Sprint 1st customer enjoying his tab#starburst incentive Rc and customer @ChappySprint @Carol_Anderson4 http://t.co/bu1trihFzl',
#  '@PontusTidemand is new Swedish champion in rally sprint Now we Looking forward to @RallySweden',
#  "Scotland's @CallumSkinner and @jmitchell49 both progress to sprint semi-finals @RevolutionUK #RevolutionSeries",
#  "Fantastic women's race in #cxworlds #Tabor2015 with great @FERRANDPREVOT beating @Sannecant in sprint; defending champ @marianne_vos 3rd",
#  'True story. Happened yesterday. Might have to go to sprint and offer the fade today. Lol. Smh',
#  'Wow. @FERRANDPREVOT edges @Sannecant in a dynamite sprint finish. That was awesome. Road &amp; CX world Champion. What a season. #cxworlds2015',
#  'What a great race! @ferrandprevot wins #cxtabor after fabulous battle &amp; sprint against @sannecant',
#  'What an amazing race! Ferrand-Prévot takes rainbow stripes over Cant in sprint, with Vos in third. Tough last lap for Nash in 5th #CXworlds',
#  "Both Cant and PFP have a great sprint - PFP's sprinted to Road Champ win, the tarmac suits her, but Cant knows that... #CXTabor",
#  'Amazing 4th place ride today by @GageHecht @UCI_CX worlds! An unfortunate cain slip winding up for the sprint. Doing America &amp; CO proud.',
#  'So make sure you bookmark http://t.co/ZGfzxqCdVZ so you can keep track of everything sprint car related on the only racing site....',
#  'Improved maximum perfomance and sprint speed by training with #PolarBeat. http://t.co/HST8XGO2Gb http://t.co/b8kvzEahKq',
#  'Joburg weather is unpredictable,  @simply_skillo and I just did a 100m sprint in the rain...thank God for pleather, nlabe ke kolobile.',
#  'Track Championship Round 15 - Sydney Speedway, NSW 1st     Danny Reidy (NT) 2nd    Sam Walsh (NSW) 3rd     James Thompson (NSW)',
#  "@HarpSwim What's a sprint? Not worth getting wet. Distance Champs tomorrow! Have fun @Berko_swim #goodskills",
#  '22-year-old Coline Varcin socrss first career win and sprint Gold at Otepaa. http://t.co/Rbt2OT5R7A',
#  'CLUB CHAMPS! SPRINT CHAMPS! TODAY! The excitement is just unbearable! #sprintchamps #speeeeeeeeeeeed',
#  'Just beat a 121-25 team in a SnD Wager w/ dedo and my sprint button decides to completely stop working last map and we still won.',
#  '#tracknats QLD’s Brooke Tucker wins the under 19 women’s sprint in three heats over Tahlay Christie',
#  "Franjic. Easy tiger, you're on a yellow. Team needs you. Marathon not a sprint. @Socceroos #ACFinal",
#  'Looking forward to Monday’s Scrum Breakfast Club - Open Space on Sprint Planing. Looks to be the best attendance yet! http://t.co/sgpmV4YYtQ',
#  'Full analysis of Bergen Sprint Camp Nightsprint. Intriguing route choice legs &amp; top runners http://t.co/BSHtvsZHFB http://t.co/MPtgNINAre',
#  'Team Sprint HS134 is starting in 5 minutes. You can read live results at this address http://t.co/T34p1xNL2t … or following us ;) #fisnoco',
#  '@IllawarraCC illawarra juniors sprint podiums nsw junior track champs http://t.co/EV71EKiRqt',
#  "Backing up last night's sprint gold medal, Sam Webster has beaten a stellar field to win the men's Keirin at the #NZTrackNats.",
#  '@CDelaneyNC paired with @skiwardo  in todays team sprint in @fiemme2013. First world cup start for Colin! Go Get them boys! Have some fun!',
#  'Nuclear Reality wins the second @TPMenangle for  @CjHarmey @osbornj20 with a strong late sprint http://t.co/gm9EWxiZfv',
#  'Visit @VirginActiveUK Aldersgate 3 Feb for 500m sprint challenges for prizes @SKXPerformance - non members welcome! http://t.co/gbHiboxNPs',
#  '#tracknats Brooke Tucker will meet Tahlay Christie in the U19 women’s sprint after Tucker upset world champion Field in semi final',
#  'Good luck to all our swimmers in Sheffield today at the yorkshire Sprint championships! #LetsGo #Creatingchampions',
#  'LIVE RESULTS are coming through nicely at http://t.co/7XhtW1H7qy. Stay tuned to every throw, jump or sprint here: http://t.co/NcwMiEpex7',
#  'Sprint Triathlon Training: A Time-tested And Perfected Training Formula. This Formula Is A Simple, ... http://t.co/trOyjFAPRV #Triathlon',
#  'This morning from beautiful @fiemme2013 is the Nordic Combined Team Sprint HS134/2x7.5K at 10.00 CET :) #fisnoco',
#  "@morganleexxx Look! It's the lineup for the 2015 special-Olympic sprint challenge!",
#  '@motterms always a great sight when the haulers are getting ready to leave. #RacingSeasonIsUponUs',
#  'The Design Sprint from Google Ventures. A wonderful resource for ideation . #startup #entrepreneurship #google http://t.co/HSSOn9XUBZ',
#  'Permanently Unlock your Sprint iPhone 6/6+ #Fast Processing 3-8 working days #Guaranteed Unlock #Money Back Guarantee 100%',
#  "Inside Report: Led by Charlie Villanueva, @DallasMavs sprint past Heat for Rick Carlisle's 600th career win http://t.co/8iD6G93QJo #DALatMIA",
#  'Ate a lovely dinner and threw it up on the mile sprint back to the hotel 😊',
#  'He told me drop them panties like a sprint call 🙈🙊',
#  'The ASCoC season starts February 5th! We will have LIVE UPDATES on the Florida Sprint Car Races including both the ASCoC and the WoO!',
#  'Can you believe @dnlsuarez bested our Sprint Cup drivers in the @ToyotaRacing Gridiron Challenge!? Good job @ARRISEVERYWHERE driver!!!',
#  'Sprint be like http://t.co/ljAVOnfue8',
#  'SKODA TRACK CYCLING NATIONALS – DAY 3 MORNING SESSION  World Champion sprint stars come out to play  After... http://t.co/yHQy5bMLeS',
#  "We're counting down to the 2/14 #NASCAR Sprint Unlimited Cup event at @DISupdates with winner @DaleJarrett http://t.co/yiuDlZZT19",
#  '#SWT winner @ValeScandolara (Orica-AIS) takes two-up sprint from Tess Fabry (High5) for second place at #CadelRoadRace.',
#  "INSTANT ANALYSIS: Led by Charlie Villanueva, sprint past Heat for Rick Carlisle's 600th career win http://t.co/8iD6G93QJo #DALatMIA",
#  '“I think he’ll be fine,” says Bill on son Chase heading for Sprint Cup. Says he has a good head on his shoulders and good people around him',
#  '#TrackNats Junior World Sprint Champion @CourtneyField1 shows off her rainbow stripes in sprint qualifying. http://t.co/YoJHzYTRex',
#  'Currently in the Sprint jersey at the NZCC thanks to some solid work by team mate @scott_swt @d3rt @FocusBikesAust http://t.co/BTSFyyiqRq',
#  'Google Ventures shares their Design Sprint methodology to the world on the web/in a book - http://t.co/ezhsN4o2iW - we love it at @Sanomalab',
#  "@jayemm173 You got this, Jenn! Keep working towards your fitness goal. It's a marathon, not a sprint! It's hard, but definitely worth it!",
#  'the only people that text me is tekeira &amp; sprint 😢 sad but true',
#  'Live life like a marathon not a sprint.',
#  'The Design Sprint —Google Ventures: "Ability to build and test nearly any idea in just 40 hours." #rapidprototyping   http://t.co/BO4HLgjXrO',
#  '@sprint ypu need help from @TMobile please help @TMobile nothing loads on @sprint network',
#  '5 Timeless Prince - looks terrific and coat glowing..1 Greatwood looks forward enough can sprint well fresh @TVNTVN',
#  '@suckmyelbicho @sprint don\'t do it boogie. Yeah, their plans r cheaper, but coverage area is super sketch. And was basically told, "oh well"',
#  '.@MatthewGlaetzer is the National Sprint Champion! #tracknats #cycling #WWOS http://t.co/M0RcjLoSkM',
#  "Hey @sprint why don't you cut your rates in half for EXISTING customers?",
#  "Why don't people realize a 400 is a sprint not a high speed jog at comfortable limit.",
#  'Testing Sprint, T-Mobile, Verizon, AT&amp;T: Who has the best cell service in Cleveland? http://t.co/czCHgLmh40',
#  '#NASCAR Sprint Cup champion Kevin Harvick presents Rex White for induction into the #NASCARHOF.',
#  'The race has reached #torquay and now heading to #BellsBeach following the second sprint #Subaru #NRS15 @CyclingAus @CadelRoadRace',
#  'i love when refs call fouls then just let them go and sprint off the court',
#  '.@MariahForward @GHLForg Remember #advocacy is a marathon not a sprint. Your testimony was powerful.',
#  'Goal! @MerrillTrent on the 50-yard sprint gets behind the TC defense and slots the ball past thd keeper. Assisted by @RileyUnger_.',
#  'Sprint winners of the jbl contest on the way to a meet and greet with Pitbull. Super night before super bowl. http://t.co/vLjJhqzVV3',
#  'This leg just set 2 more records and top sprint qualifier.  #BlackSwanMagic @InsideWAIS @CyclingAus  #TahlayChristie http://t.co/Q8f3RAaLce',
#  '@xsantv @AdamGullion91 Sprint Rockin our Dirt Defenders. We love all racers haha #FLAXSAN http://t.co/yVBacZCB1t',
#  '@Nune44 @sprint Lol fo sho!!! I tweet sprint about it all the time lol...good thing my contract expired last week #imoutsprint',
#  '.@sprint ah seriously, get out of here with that! @TMobile is the best. Loyal customer for 12 years for a reason.',
#  '@Relax2Live @RollWithSoul @kgbond0007 @BrianMCheney Another happy family switching to #Sprint #sprintse #ByeFelicia http://t.co/7vLlVLLHTm',
#  "In the under 19 women's sprint Tahlay Christie qualifies fastest with new Aus Champs and all comers record. 2nd @CourtneyField1",
#  'I just got off the phone w #sprint- the lady said "don\'t forget to smell the flowers" is that like code for smoke weed? 😂 #IntoxicatedTaurus',
#  '✓ WIN the Practice  ✓ WIN the Workout  ✓ WIN the Drill  ✓ WIN the Sprint  ✓ WIN the Meeting  ✓ WIN the Moment  ✓ WIN THE DAY!!  #MyRB',
#  '@sprint yeah but with @TMobile after 24 months you own the device, with sprint you are leasing it #TMobileAllTheWay #ReadTheFinePrint',
#  '@HIGHForTHIS__x lol well I switched to Sprint so I have unlimited data',
#  '"After more than 100 sprints with startups, we’re ready to share what we’ve learned" http://t.co/Nohz76WfmM #google #design #sprint #process',
#  'Get your red dress ready Kc! #KCGoesRed @AHAKansasCity @saintlukeskc @sprint http://t.co/M4YnOBs4S9',
#  "Go red at Ra! @AHAKansasCity who's celebrating with us?! #KCGoesRed @saintlukeskc @sprint http://t.co/CVNjGwusur",
#  'Sprint on over to our special link to catch the early-bird deal on  THE RIVETER: MARINA BAY 5K AND HALF MARATHON!... http://t.co/4ETGAZOdPC',
#  '#ItsOkayIf you secretly want to sprint as fast as you can out of school the second the last bell rings…',
#  '@sprint @ATT @Verizon Sprint, as a consumer i ask you to please improve your service. Your network works nowhere while ATT does most places.',
#  '"The Design Sprint"  from @GoogleVentures: a 5-day DIY process to mesure and validate #Startup products http://t.co/hkMHHOYaYj #Lean #Google',
#  'Loving the Design Sprint, from @GoogleVentures: a 5-day process for design, prototyping, and testing with customers. http://t.co/24kPmLaJZl',
#  'Actors @James_Phelps and @OliverPhelps sprint down the line of fans giving high fives at the #HPCelebration http://t.co/jnTywnUXmd',
#  "#Heartbreaker3 is looking to be one of the biggest events of the year 🙌🙌 DON'T MISS OUT 🙌🙌 CBE 1407 GRAND ✈️ INSIDE THE SPRINT CENTER 🔥🔥",
#  '"@ComedyPics: YOU CAN\'T SPRINT WITH US http://t.co/zr9W66CGwn"@meganbruce98 @cammieallan97 @danaadavis69 oh my god',
#  "Craig Evers wins 2nd sprint has 14 points. Scott Thomas 2nd now has 10 points as does Jason Christie who hasn't figured so far this morning.",
#  'Boycott @sprint for supporting Super Bowl 2015 until @nfl fires Roger Goodell @nflcommish http://t.co/2JEjyWuV5J http://t.co/AXuy5pStV8',
#  "Some clips from today's rally test with codriver @emilstwit Swedish Championship in Rally Sprint at… http://t.co/Rqw26wY5od",
#  '@DeutschInc want to see your @Sprint #SuperBowl spot baaaaaaad #CRSuperBowl http://t.co/gVcR0w7G07',
#  'Sprint, jump, slide and more! Head over to the @unity3d #AssetStore for a sweet deal  http://t.co/8k9Nz6TsAe http://t.co/yM7mpatZfC',
#  'Great result for @oneleggedrider and the rest of the GB riders. Bronze in your first ever team sprint! #teampreece',
#  'If working life is a marathon, not a sprint, this afternoon has truly felt like the last 2.2km of a 42.2km week.',
#  'Perfect timing as we are starting a #Design sprint now. http://t.co/sMYuXYIivL by @GVDesignTeam #Payroll like uve never seen b4 @raydawg88',
#  '.@KevinHarvick is the only driver to win Sprint Cup @NASCAR_XFINITY &amp; @NASCAR_Trucks races here. #FridayFact http://t.co/uVyx46cn8C',
#  'Superb meeting about mobile phones for public service @USC_CCLP @WhiteHouse @TMobile @sprint @internet_org @google http://t.co/gD4UwXIR6S',
#  'Our awesome @GoogleVentures designers launched a site about their design sprint process, they’re also writing a book! http://t.co/KC5im1yWmS',
#  'Thanks to Peluso Open Water for sponsoring the swim course at the RTC Sprint. A pre-swim will be on March 22,... http://t.co/yWEbVYoEzc',
#  'Sprint has been good to me lol let me go ahead and pay my phone bill.',
#  'Nice! “@Knighter01: .@TBR_Racing confirms @AlexBRacing to drive No. 7 Chevrolet in 2015 #NASCAR Sprint Cup. #NASCAR”',
#  'VIDEO: Comedian Kevin Hart challenges NFL star Adrian Paterson to a 40m sprint at 1am!… http://t.co/c3aZ1ZCxmW http://t.co/CC6piiAWOn',
#  "Someone can toss a ball? much wow such hero, bet they can't fight Ebola and sprint into war-zones to help people. #FF @MSF &amp; @SyriaCivilDef",
#  "I wish I was one of those girls who are naturally great runners and can sprint 5 miles like it's nothing",
#  'Wow @IndyLights faster than @NASCAR!  @KyleKRacing @juncosracing recorded a best lap more than 7 mph faster than the Sprint Cup lap record',
#  "@cheyenneeford @4ever_young209 I'm about to take my ass to sprint and turn your phone on 😐 but sounds good babe",
#  'Win a @HP Slate! Join us @TopTowerPhilly Feb 11 Hear @comcast and @sprint IT Process Automation success stories RSVP http://t.co/r3z7t0tNBu',
#  'Wishing 1 of my absolute favorite sprint car drivers&amp;all around person @DaleBlaney a VERY Happy Birthday! #never2old http://t.co/1aXYCfpwRv',
#  'Join me at Chichester Westgate Triathlon Standard &amp; Sprint Series 2015! http://t.co/ylbSGGJ3iD',
#  "It's Friday and I'm feeling crazy.  First Sprint PR associate to reply, and list 3 benefits of a G3 over an S5 wins a Nexus 5 phone!",
#  'Congrats to NZL Sprint Champ @stephmckenzie93 ! Yeowww @CyclingNZL #NZTrackNats',
#  '@Keith_thatgood @TMobile @VerizonWireless @sprint @ATT nigga tagged ALLLLL the big boys like fuck it lol',
#  'Sprint to save on Puma, Reebok, Nike and Adidas shoes from under $35 at @FinishLine! http://t.co/ExLmPUVeBM',
#  'Knight Prototype Fund - seeds small projects to get 6-month sprint. Come back and share your learnings @knightfdn #alamw15',
#  '@Murray_Kinsella Love watching Gilroy, whoever is controlling him manages to press the sprint and spin buttons at the same time.',
#  'Only @jBainbridge3 and I would sprint mid-lunch at the caf to go get free Currito!',
#  'If Anybody Selling An IPhone 6 Or An Upgrade For Sprint Holla At Me Throw A Dollar At Me 🙏 Trust Me The Price Is Worth It',
#  '2:20 Lingfield (31st Jan) Expert Sprint Race Analysis From Eric Winner. Read more http://t.co/qlz3uBTIsK @LingfieldPark #racingtips #betting',
#  '2:20 Lingfield (31st Jan) Expert Sprint Race Analysis From Eric Winner. Read more http://t.co/LH3OU6TgtI @LingfieldPark #racingtips #betting',
#  '2:20 Lingfield (31st Jan) Expert Sprint Race Analysis From Eric Winner. Read more http://t.co/DiLTVr3Wlm @LingfieldPark #racingtips #betting',
#  '"@_PlugLove: Sprint just like Comcast, try to leave they gone try to throw you all kinda deals" 😂😂',
#  "I have always told you that it is not a sprint. It's a marathon. So proud that you stuck with your commitment! #loveu http://t.co/HaHBjqk1sw",
#  '@FreakoSuave103 @nickibabyy21 is Tmobile service better than sprint ?',
#  "Embedded M2M Solutions - Sprint Executive Lays Out Carrier's Vision for Future of M2M, IoT http://t.co/OT2VnrgmXE",
#  'Great SHU WPF midday sprint with @savagewri\u200btes @jspoonwrit\u200bes  927 words in 20 minutes.#SHUWPF',
#  "Know your definition of done will evolve? Don't make it hard to deliver working software in 1st sprint ^ @neil_killick",
#  'Bergen Sprint Camp,  getting ready for the first race! https://t.co/FnkjAZx78n https://t.co/3Qu2dQeVUo http://t.co/B94LHANjk4',
#  'Sprint Cars Join Easter Bunny 150\xa0Lineup http://t.co/0kukKiNgKS',
#  "Ready to step into Team Tätab's #FordFiesta #WRC &amp; fight for the Rally Sprint Champion title tomorrow! #SMveckan http://t.co/47BoUp37oy",
#  'Busch finishes a sprint to applause from fans, "Not bad for a 38-year old," he says. #cf97',
#  '@mart1buch: Monitoring changes in Jump &amp; Sprint Perf: Best or Average? http://t.co/VFwWKFwvcm @HaniAlHaddad2 @benMsimpson Nice work guys!',
#  'Earlier this week Pie was euro stepping now he the 100 meter sprint champion 😭😭😭🏃💨😩😩😩',
#  'Sprint, Olympic, Ironman? Taking on a Triathlon? then download our FREE nutrition guide! http://t.co/9PEsMD9mV8 http://t.co/oNCiHmHTr5',
#  'Kim Collins is dispelling all the myths about sprint ability beyond age 30-we can learn a lot from his training..',
#  "'Not a sprint, a marathon' -German defence minister on modernizing the #Bundeswehr http://t.co/w6pNGtUfOm http://t.co/n1WHUUZYUP @dw_english",
#  'Drop them panties like a sprint call.',
#  '@delandmoneygang @Relax2Live @BrianMCheney @DMGod13 @RollWithSoul Help your bank account get SWOLE with savings from #sprint #WHATWHAT',
#  "'It's not a sprint, it's a marathon' -German defense minister on modernizing the Bundeswehr http://t.co/x9wKhlIhTO http://t.co/QwymuT0F6r",
#  'if you got sprint and pay ya bill every month..lol ya rich',
#  'this morning further reading reveals there was nearly a sports model called the Frisky Sprint http://t.co/wBwovDhwS7 #brandnametrickiness',
#  'Woot!  Chicago :: Mayor Announces Deal with T-Mobile, AT&amp;T, Sprint and Verizon to Bring a 4G Network to CTA: http://t.co/F5WqrNvRSI',
#  ".@sprint wow that's some pretty sad feedback @sprint ... Guess you can't even give it away ! #sprintlikehell",
#  "End of our sprint @thomashazledine may not be here but we've saved his seat #agile #friday @enshrined @peachhhyyyyyy http://t.co/75dn1L9fio",
#  '@liosbikes @BritishCycling @WalesVelodrome thanks for that. Team sprint against @jodycundy @CrystallLane @oneleggedrider .... No biggie 👍',
#  'Sprint 6 Plus $400 Great Condition http://t.co/TJEf1Q7qDc',
#  'Getting ready for a Sprint Demo with our #InsiteForSitecore customer #SitecoreScrum /cc @himadric http://t.co/Z3Eq7KC6wv',
#  'Happy Sprint anniversary Anna!   Apprecaite all you do to help us.     @MidWestSSR @RunJimboRun',
#  "I saw Slick Savi trial at Romford on Tuesday.  He shouldn't be 8/1 to win the sprint tonight (8.34pm)  Showed good speed, is plotted up.",
#  'Anastasiya Merkushyna at the finish line, hoping for Gold. She did win; IBU OECH Junior Sprint… http://t.co/00X4g3FRrd',
#  'Just had a nice sprint to catch the bus after movie with @ltsclarence @ClementiMinus1i @schoko_18lade',
#  'I like everything about the new Big Boss model and really love the animations  I think Big Boss running is the best sprint animation ever',
#  'RT @LarryMac28: Wow, Only 23 days until our 2015 Daytona 500 on @NASCARONFOX &amp; drivers on track 2 weeks from today Sprint Unlimited Practice',
#  'Wow, Only 23 days until our 2015 Daytona 500 on @NASCARONFOX &amp; drivers on track 2 weeks from today Sprint Unlimited Practice @FOXSports1 #fb',
#  'Oh Snap: Sprint’s Super Bowl ad will call out AT&amp;T and Verizon [VIDEO] http://t.co/p81nKVRLmL http://t.co/M65V3CKt8q',
#  'Gail challenging the boys at 60m sprint #thisgirlcan #leadership #Athletics http://t.co/pAvBSrFpm4',
#  'Jeremy Filosa of @le985fm Montreal joins @BrunySurin Celebrity Sprint Challenge @j_filosa #ACIndoorOpen http://t.co/ZLe5cyuJ0p',
#  'Happy birthday to my favorite sprint car driver @DaleBlaney #lowrider',
#  'Finish coming for the Trofeo Andratx in Majorca, looks like sprint from &lt;20 riders',
#  'Reaching a big goal is less like a sprint and more like a marathon.  Thanks for sharing the clip Mike. http://t.co/ut6GzocFyN',
#  "Come down to Broad and Market Sprint Get you a phone I'll throw you a free Tablet #BlackAndYellow",
#  '.@TonyStewart – the most interesting man in the sprint car racing. #TheNewAllStars http://t.co/16KLnHeQcC',
#  'Regardless of how you feel about Sprint, this is THE mindset necessary to progress and grow any organization today a…https://t.co/BkVxdJ38r4',
#  '@SWCologne N1ce work guys! The SWDus Team wishes you a very nice Weekend! #startupweekend',
#  "Efficient #Sprint #Technique is dictated by the laws of physics, anatomy &amp; physiology. Don't just #Run, Run smart! http://t.co/p5iO1kLlc7",
#  "@carolynphan_ That was the best sprint I've ever seen",
#  '3rd sprint medal of the day! Awa in the 60m! http://t.co/xlzWuzuuep',
#  '#GO. This is the last super extra early sprint; next 1 starts regular morning times. 1 more lil push for those extra words today? #writeclub',
#  "Great sportsmanship from Meares &amp; McCulloch in women's sprint #melbourne #womenscycling #TrackNats #aussiecycling http://t.co/77xB8qWoJM",
#  "@TheArtw0rks @JohnRossArt @thebobbond @vivianwade 'Sprint Finish' now framed measures 102cm by 34cm.  Hope you like. http://t.co/1fKsm6cH74",
#  "As Romney prepares to update, listen as @poconnorWSJ explains how Bush's sprint has changed the dynamics for all: http://t.co/Fd007XCNKQ",
#  "Successful fundraising is a marathon, not a sprint. It's too important to be sacrificed because you get “bored” with the basics!",
#  'The Kazarian family along with Bubby Jones, Ray Scheetz and J.C. Agajanian Jr. after a CRA Sprint Car win at... http://t.co/AlCQgtdIcW',
#  'Excited for the #Nonprofit Starter Pack Sprint today in DC! Thanks to all the participants! #NPSPsprint @PICnet #NPSP',
#  "@sprint @ATT @Verizon I'm perfectly willing to pay more for good cell service. #1 reason I haven't switched to Sprint. #badservice",
#  "Sprint ain't shit for that tweet. 😂😂 Their services still ain't compared to Vzw and AT&amp;T though",
#  'sprint review chez #iAdvize :) #job #developer #Nantes http://t.co/LGgES7tX5n',
#  "Massive good luck to Craig Preece racing for GB today at Newport Paracyc intern'l in the mixed team sprint with @jodycundy and @crystalllane",
#  'When I am ready to sprint out of the office on a Friday http://t.co/yMySMMe3Br',
#  "@brettcoffey @discoa09 @spiderh2311 thanks Brett. No, I'd agree there. Just good that 'she's back'. Some fun over sprint trips next v mares",
#  '.@jan_schmid is the first to reach 8.6 (last inter), but it’s clear we’re having a sprint final #fisnoco #fiemme2015 http://t.co/wNe4PuipmR',
#  'Great sprint planning meeting today with the team, lot of discussions and #noestimates ;) #scrum http://t.co/nW1ni9Y5lG',
#  'Sprint Triathlon Training: A Time-tested And Perfected Training Formula. This Formula Is A Simple, ... http://t.co/SFWYxL4l4G #Triathlon',
#  'FREE download - 8 week sprinting programme. http://t.co/b8gQS2DXxr #sports #fitness #exercise #gym #running #sprint',
#  'As Google expands its fiber plans it sees a silver lining in #TitleII rules for ISPs. Sprint seems to agree: http://t.co/ufcb8oMvRq',
#  'National title no. 33 Proud to be Australian Sprint Champ 2015 #aussiecycling #TrackNats http://t.co/8BLFg50d6Y',
#  'Must See Racing Sprint Cars To Join PASS Super Late Models For Easter Bunny 150 At Hickory  http://t.co/GweLJMPfG0',
#  'Must See Racing Sprint Cars To Join PASS Super Late Models For Easter Bunny 150 At Hickory  http://t.co/SlkKqka1Zs',
#  '#Monitoring changes in Jump and Sprint Perf: Best or Average? http://t.co/5cdb6hEw0s @HaniAlHaddad2 @benMsimpson http://t.co/qIWvMzoNrp',
#  'Acceleration and sprint profiles of a professional elite football team in match play http://t.co/NdhIzGXJzx',
#  'Really happy to take away the silver medal in the sprint tonight! Thanks so much to my parents for… http://t.co/ZF9ycTk9RZ',
#  'What does it take to have a successful Sprint Planning meeting? http://t.co/YY4niKciAu  #agile #scrum http://t.co/VGeb4jBFCD',
#  'Bale was paired with Ødegaard for a sprint. Needless to say, Bale won. But he offered Ødegaard some advice after. http://t.co/PSEfHsQqJ9',
#  "If you already In a 2 year contract why don't cell phone company like @Verizon @sprint just let you enjoy upgrades any time.. #moneyhungry",
#  'Lessons learned 5 day #productdiscovery sprint: #Persona #co-creation shifts team discussions from features to solving needs @podojo',
#  "Sprint finish in the women's 800m free with @JessicaAshwood taking top spot in 8:24.04 with Becca Mann from @USASwimming 2nd in 8:24.13",
#  'Day 5 product discovery sprint kicked off with parallel teams creating a #userstorymap and #valuepropositioncanvas',
#  "Alex Rendell wins under 19 men's points race in final sprint. Teammate Michael Storer silver and Rohan Wight bronze. #tracknats",
#  'A long sprint lead out, a world champ attacking over the top + an underdog fighting to follow =an entertaining pointsrace @CyclingAus @WWOS9',
#  'Well well well looky what just dropped into Tweetymike Towers: only a @feedbacksports Sprint workstand! #cantwait http://t.co/U5SkKm64O9',
#  '#tracknats Hoskins with an unassailable lead with one sprint to go. 3 laps to go… Who will take silver - world champion Cure or Manly?',
#  '@MatthewGlaetzer and @AnnaMeares Sprint National Champions!',
#  'Awesome Sprint Race Map 1.8.1, 1.7.10 and 1.7.2: The Awesome Sprint Race Map for Minecraft 1.8.1, 1.7.10 and 1.7.2… http://t.co/jL6ozINYWI',
#  'Lessons learned on product discovery sprint: culture eats strategy for breakfast - innovation in an existing context #leanchangemanagement',
#  'I done a full sprint to catch my bus for a long distance and when I got on people were applauding me😂😂😂😂😂😂',
#  "#TrackNats @MatthewGlaetzer wins the men's sprint final in straight sets against Peter Lewis",
#  "#TrackNats @AnnaMeares wins her 5th women's sprint title in 7 years! @kaarlemcculloch with silver. The pair embraced after the line",
#  "#TrackNats @StephMorton28 wins the women's sprint bronze medal - leads from start to finish in the second heat against Ward",
#  'How do you wish to travel: Fly? A lightning-fast sprint? Teleportation?! Tell us your own Superhero power and name with #KeepItReal and win!',
#  "@FriNightWrites  WooHoo! First ever sprint, Yay! 567 words. That's a good day[night].",
#  'Throttling network speed during a sprint review using @googlechrome developer tools to show network performance optimizations. #perfmatters',
#  ".@stephmckenzie93 wins the women's sprint over @NatashaHansen01. Goes to 2 from 2 so far this week. #NZTrackNats",
#  '#nzcc full results stage 2 and GC  (big gaps) , Final sprint by @Craig__Evers ,@DionSmithy  best U23 ,@RhysGillet KOM http://t.co/HIImFmAjwn',
#  'Profit From Udemy – The Stress-Less Sprint http://t.co/NVBAcXVigM',
#  'Why when I want to talk on the phone sprint wanna play',
#  'This presidential race is a 10,000m not a 100m sprint, and how well you perform in the last 200m determines your position in the race.',
#  'Can you please just send me a new phone? 10+ year customer. Already paid 170 for 1 replacement phone. @sprint @sprintcare',
#  "Unbelievable. Looks like I got 2 defective phones this month to replace one I dropped. Good job. Won't charge battery. @sprint @sprintcare",
#  'Meredith Grey is absolutely wholly and completely my sprint animal rn',
#  '“@The_Carter1: "Sprint told me I gotta give them $500 plus my 5s for the 6 man if Yall don\'t suck this....nvm nvm 😒🌵” 😂😂😂',
#  '#SampoorneshBabu Cameo in #Vikram Movie http://t.co/Se9JcNepHf It takes years to come, succeed and become popular in film industry ...',
#  'Unable to sprint or throw a ball very far, she was nevertheless adored by border collies #myozobituary',
#  "“@TashBaeless: For the first time in life I don't owe Sprint any money 😩😩🙌🙌🙌” Look At God!",
#  'Profit From Udemy – The Stress-Less Sprint http://t.co/gqqqQsEWux',
#  'Tony Stewart buys sprint car racing series: ... reigning World of Outlaws Sprint Car Series champion Donny Sch... http://t.co/sRUS8WhBPZ',
#  '&amp; bye to good service too.  RT @sprint: "Say goodbye to your costly Verizon or AT&amp;T plan http://t.co/lhNXX1LKjA https://t.co/cDZlWJYx5r”',
#  'Somebody...anybody.. Please fwm on a Sprint phone because the next person to cap me catching a fade',
#  '@sprint_MEDLEY congrats !',
#  'Sprint will apologize to AT&amp;T and Verizon during the Super\xa0Bowl http://t.co/w4pd7MbWKj',
#  'I WENT TO THE SPRINT STORE BC MY MOM HAS SPRINT AND I PROMOTED NASH BC IM COOL http://t.co/2c1WM5bUGI',
#  "Shoutout to @TinaDayton's hair ties for helping me super sprint in a circle. #AchievementGrindingMadeEasy http://t.co/vbhQvt2fzG",
#  '"@HeffnerRacing: Jerry will be running the USAC midget schedule, most ARDC shows and some USAC sprint shows" awesome, favorite midget driver',
#  '@SpeedShiftTV 6" of fresh snow and sprint cars for the wisconsin boys!  #saturdaysrfortheboys https://t.co/Gdhr3XHutL',
#  '. Welcome to the party @sprint ! You may have a few people using your service that would like to #PayWithLitecoin ... could you add #litecoin as a payment option to pay our bills? Thanks in advance. CAN YOU HEAR US NOW?  Contact:  @SatoshiLite',
#  'Coworkers in their natural habitat 🐯🐵🐸 A snap from the last ‘Work Sprint’ in our January series! These have been such a hit that we’re planning to continue them on a monthly basis - more details coming soon!  #community #workforyourselfnotbyyourself\xa0 #coworking\xa0 #weareyqq https://t.co/iYrGAoXZU3',
#  "ROY H got a bunch of $$ for breezing in company in the G2 Palos Verdes. The 2017 Male Sprint Champ hasn't lost a step since his Breeders' Cup W. Read the recap here: https://t.co/7H4MWJjoro  Jockey: Kent Desormeaux Trainer: Peter Miller Owner: Rockingham Ranch 📸: Benoit Photo https://t.co/hvQ5IQcqpM",
#  '@zacharyfrivera @MissGittles @johnhomsombath @NorCalRetail @SmSteele03  3rd winner down here at florin rd sprint there is still 1 more chance at 4 https://t.co/qBCDPOtaNT',
#  'Sprint iPad just clocked 114Mbps inside @Best_Buy_Mobile Can your iPad do This? This is why @hulu is awesome to stream while on #Sprint network. #iPad #Apple #LTE #RENO #RenoNV #BestBuy #FastDontLie #iPhone #ios #ad #Hulu @Speedtest @openspeedtest https://t.co/GjgStXGuEO',
#  'Bringing home some hardware at Sprint Championships! https://t.co/U97sajADqS',
#  'This would be Greencastle’s Emma Wilson, at the 2018 Sprint Showcase At Wabash College. Milesplit says this is best time in national database. https://t.co/4iInXNrynp',
#  'Pretty good day at the Sprint Championship Meet for Eastern—1st overall, 1st Girls, 3rd Boys, 1st both Corkscrew Relays😃 https://t.co/8JENP09F6n',
#  'Triple Crown nominee #Mitole, at 2-5, wins maiden allowance sprint in 1:09.75 in nightcap Saturday at Oaklawn: https://t.co/F4fyxK4c31',
#  'Triple Crown nominee Mitole ($2.80) the easiest of winners in R9 (MSW sprint). @RSantana_Jr for HOF trainer Steve Asmussen. 6F: 1:09.75. King Cotton went in 1:09.85.',
#  'Stoked to ride a new flying 200m PB of 10.206 here in the National Sprint Championships! I came… https://t.co/dPMwhXx5u4',
#  '5G Data Spectrum will increase the Price of Data Plans according to Sprint CEO https://t.co/r6teIQhyaz https://t.co/9KbDOsdQT5',
#  'Happy Bega Cup Day! We have Just A Spat R1, Alfden &amp; Athonis R4, Tyres Are Crucial R5, Wonderbolt &amp; Chasing Charlie R6 - The Bega Showcase Sprint, Almost Court &amp; Rock On Zariz R7 - The Bega Cup and Le Sacre Blur R8.',
#  '@johnhomsombath @MissGittles @NorCalRetail @SmSteele03 @1025Radio  First happy winner down here at the Florin Rd sprint store still 2 more drawings today come check us out https://t.co/jHncD0TOJe',
#  '@johnhomsombath @MissGittles @NorCalRetail @SmSteele03 @1025Radio  another happy winner down here at the Florin Rd sprint store still 2 more drawings today come check us out https://t.co/q182R8RFkM',
#  'Slow and steady wins the race. Work and life is a marathon, not a sprint.',
#  'Love and hugs at the finish line at the World Cup Snowboard Cross Sprint Finals  Watch more at https://t.co/Znmsyh1kRs https://t.co/qbrealoPCB',
#  'Starting a design sprint in Lisboa. What a beautiful city! https://t.co/HqPsdR2BmJ',
#  'steven_perezluha leads @THE_GUTT out to a perfect victory sprint at the Gainesville Swamp… https://t.co/j57VBajVV2',
#  'Went against some very tough competition today... some of the best in the country. Finished Top 6 but I’m not satisfied. Greatness isn’t made in one day. It’s a marathon not a sprint. Back to work this week to get ready for UCO Meet next week. Trusting the process...',
#  'Sprint champion #RoyH with @DesormeauxKent wins G2 #PalosVerdes @santaanitapark for #RockinghamRanch and @petemilleracing @benoitphoto_ https://t.co/KKs4Xzsizo',
#  '@sprint Oh my god why are you teaching it??? Hasn’t anyone heard of I, Robot???',
#  'Clarence sportin his 1st smart phone ... Choosing Boost was pretty smart too! https://t.co/14HhkDDeqL',
#  'Congratulations to Steve our VPL at Bestbuy Warwick on finishing in the top third for January! He won himself a Sprint Jacket too!!! https://t.co/IdZxK7nEtj',
#  '@JoeY_Sprint @WestfieldSA @blee01 @Sprint_West you guys look great Team Santa Anita! Highly Motivated like always! 👌🏽',
#  'Welcome to the party @sprint ! You may have a few people using your service that would like to #PayWithLitecoin ... could you add #litecoin as a payment option to pay our bills? Thanks in advance. CAN YOU HEAR US NOW?  Contact:  @SatoshiLite  @LTCfoundation',
#  "Now that's pretty cool... @TEPPlus providing #TechExpert tips and tricks! I COULD USE THIS!!!! #wegotyoucoveredFL @Sprint4FL @Sprint_PR @SprintEast https://t.co/ge8uUFFgtX",
#  '🇨🇦 @JasminDuehring and @stephroorda pick up an early sprint win in the ladies Madison 💪  Things are looking ominous for our leading ladies 😏  #SixDayCopenhagen https://t.co/w41l9jMfKH',
#  '@1025Radio  @johnhomsombath @MissGittles @NorCalRetail @SmSteele03  Ksfm out here all set up stop by for a chance to win some comedy slam tickets every 30min from 2:30-4:00 today at Sprint on Florin Rd https://t.co/4NjkSkE6Dv',
#  'The queen stage of Volta a la Comunitat Valenciana did not go as the team had hoped. Tomorrow is an expected sprint stage where the guys will look after Ryan and Colin. #learnfromit #comebackstronger #rallygrateful https://t.co/RiAu9E3u64',
#  '#NEW  4 Plz RT it :) Sprint eyes mobile 5G network launch for first half of 2019 https://t.co/K1IzpNHU2n https://t.co/26TWX8uCDt',
#  'DO NOT MISS this deal!! The UA Speedform Sprint Elite is now only $49.99. This ultra aggressive shoe will give you an edge against the competition this year! Get it here: https://t.co/06LKPWEMki',
#  'Great performances at the https://t.co/SoZ1ubYmTm Sprint Showcase meet!  4x200m relay of @aye_jaban, @isaacguerendo, Chris Smith, &amp; @sammy_bullock3 set a meet record at 1:32.41!',
#  'them niggas in castleton that sell the shoe cleaner press you harder than the sprint workers lol',
#  "Possum Nuggets Girl's Sprint Medley Relay (Thorburn, Montoye, Manly, and Raab) ran a 4:38 to qualify for MITS State Meet. Congrats!",
#  "@uoflpronghorns @sandralatrace a blur on her way to winning the women's 60m sprint at the Bison… https://t.co/w7NiqjIwAW",
#  '@JasonJohnsonRac we are super excited for the @WorldofOutlaws season ahead and proud to be supplying your racewear. #p1posse @sprint_central @OvalExpress @SungoldStadium https://t.co/NSLvG98ZWC',
#  "For those with not a lot of money but want to invest in bitcoin or stocks, try Robinhood  Sign up for Robinhood to invest in Bitcoin and stocks, and we'll both get a free stock like Apple, Ford, or Sprint! https://t.co/lp2mgVB53R",
#  'Male sprint champ Roy H looked like he was out for a morning breeze there, easily disposes of his three rivals in Palos Verdes. Has won 6 of last 7 and would have won that seventh if not for being bothered by the loose Drefong. True pro.',
#  'Very important to run your own race. Remember, it’s a marathon not a sprint.',
#  "Thanks to @GreyhoundChan for getting me the presentation photo from Southland Park's Festival of Stakes Darby Henry Female Sprint Championship! Killer Rona was the winner. https://t.co/q0Mp38mt3Y",
#  '#RoyH time! #SantAnitaPark   46k of 56k in Place pool on #BreedersCup Sprint Champ with 6 minutes to go  I LOVE #Americanize but can #RedLightning complete exacta here? https://t.co/2KaKEAa1rJ',
#  'Idk how Modric still has the energy to sprint this late on. He should be paid 3 players’ salaries since he covers that many positions at once',
#  'Back on the sprint podium - @CaitlinWard37 took a sensational silver medal. Photo: Tim Bardsley-Smith https://t.co/EABYp1ZVMD',
#  'Cerretalto (7-1) blows by race fave, Foreset to win race #7, and AlwNW2 sprint at Aqueduct. @DavisJockey /Bond. 1-6-4-5',
#  '.@TampaBayDownsFL 8th: #9 Elusive Exchange has been on @BDiDonatoTDN’s watch list since last meet. Should step forward here second off the bench and might just like to turf sprint. #NJX https://t.co/ejGmZd3FQY',
#  '“Gotta catch ‘em all” ... Come catch your favorite #Pokémon at your local #SPRINT. 630 Nordahl RD. Suite A/B San Marcos. Ricky is your guy , he just caught a Mew 2. #PokemonGO #SuperBowlSunday #SanMarcos #rare #Legendary #LiveUnlimited #iPhone #SaturdayMorning https://t.co/bVoARiGH5k',
#  'Lewisfield ($4) continues to get better and better for trainer @runcoracing and overcomes tricky inside trip in race 8 @LaurelPark to win second-level optional-claiming sprint in quick 1:08.95 under @jockeyAboca. 4YO son of Great Notion is now 6-4-1-1.',
#  'Just got my scooch case for the 7+ and I love it! #Scooch #ScoochTrain #Sprint… https://t.co/cKyRopCEIi',
#  'Stoked for the #SuperBowl2018 tomorrow?! Looks like this @sprint ad is the one to watch! https://t.co/AWnnDPkp2N',
#  'Stakes Saturday starts off with cheetahs and greyhounds teaming up for a title. #3 Bgr Cheetah from the Boeckenstedt Kennel lights up the tote board at 16-1 to take the $30,000 Sprint Championship this afternoon at Naples.  Two more heavyweight title bouts on deck later today! https://t.co/N3kued8cSZ',
#  'Stop by our location Today for half off Glass Screen Protectors...Also We have IPHONE 8 BUY ONE GET ONE FREE our unlimited freedom plan including HULU...got a credit union no problem we can get you 100$ per line you switch over!! #sprint #unlimtedfreedom #hulu  @Peter_Moreno_09 https://t.co/tlRASVuS15',
#  "@Oldfriendsfarm @ParkEquine @battles_laura I'm so sorry to see this.  I always rooted for him especially in his Breeders' Cup Sprint races (in part because he was a grandson of my very favorite, Holy Bull). I'm glad I got the opportunity to see him one last time during a visit to Old Friends last year.",
#  'Anthony is helping me sell the best deal for Sprint and Boost in town. We are ready to rock. #Sprint4Philly @BDSprintOhMi @Andieewing6 @NRSPG_ESeaton @CjDrikakis @Maantonen @powerregionwins https://t.co/04TlRopEVQ',
#  'Feeling down today.  Sometimes I have to remind myself that life is a marathon, not a sprint.',
# ...
#  'Getting ready for the team sprint on a beautiful snowy day! https://t.co/auImCf4oNs https://t.co/s0b5lcSufn',
#  'Magic. Just like that. @TravisMcCabe takes out the sprint stage here @HeraldSunTour. In Nagambie. Thanks @UHCprocycling. Made a few smiles.',
#  'Going in to complain to sprint tomrw and see if I can get something for free',
#  'Per Incanto gelding DAL CIELO wins the the 1000m sprint at @royalrandwick for @Leesracing and @SchofieldGlyn https://t.co/pfLGESRRE2',
#  '4 from 4 at @royalrandwick with our #NEXTBEST DAL CIELO winning THE CHI-X SPRINT R4 for @SchofieldGlyn &amp; @Leesracing #giddyup #horseracing',
#  '@sprint @sprintcare never bothers the reply to their customers, but they sure be calling when the bill is due!',
#  "I always like to see QB's on the move, whether it be sprint or boot off of PA. Here UL dials up PA for an easy completion #watsonbreakdown https://t.co/EJXz9q34Wv",
#  "@steveucnlive Garcia and the Golden Boy team gotta make sure he doesn't try to sprint in a marathon",
#  'I need someone to help me (force me) to write some amidst my busy schedule. Anyone up for a word sprint Sunday? Time TBD? #amwriting https://t.co/asqjSCkzjq',
#  'Why Sprint buying a healthy chunk of Tidal has net neutrality advocates shaken up https://t.co/aXG9IcKg24 https://t.co/DAgwNXgcvF',
#  "Fighting the trump era is gonna be a marathon. Don't burnout, don't sprint. Keep up the good work. All power to the people ✊🏿✊🏾✊🏽✊🏼✊🏻❤️",
#  "I love how Oliver sprinted to the door to meet his dance instructor. Oliver doesn't sprint. 🏃🏻 #POstables",
#  'For Online #HomeworkGap Help, @KCPublicSchools Students Get @Sprint Hotspots #1MillionProject https://t.co/3brjIZVso6',
#  'The Best Sprint Phones of 2017: https://t.co/k48LbQt7R5 https://t.co/sKiWidfZFl',
#  'Love is in the air! #Sprint loves to save customers money with great deals! @AAlvarez9779 https://t.co/MqqjYatj9K',
#  'Woah! #BestBuy certainly has the best savings! Come to @HolyokeMall @BestBuy for the best phone at the best price! #Sprint #SamsungS7edge https://t.co/kRiXTfwQbo',
#  'Looks like the gloves are off between @RingPlusMobile and @Sprint. Cancellation notices, lawsuits, should be interesting to watch.',
#  'More like sprint then you were swerving https://t.co/VezN5trPRY',
#  'Great to see @droga5’s @tedroyer talking w/ @JonSteinberg @kristenscholer about @Sprint’s new #SB51 ad on @Cheddar! https://t.co/9pOqAGJC7C',
#  "So true Jeremy. #Change for some is a baby step journey while others stride and some sprint...it's personalized #EngageChat https://t.co/fYeQN89PRk",
#  'Easley JV Boys sprint past JL Mann in overtime 52-47 to improve to 11-4.  #GoGreenRollWave',
#  "Sprint CFO: We Can't Go It Alone Forever https://t.co/ITC7FguyL1",
#  'Not in the 40 but definitely in a 100m sprint https://t.co/GVxa555u6s',
#  'Awesome to see #SanDiego students get their @Sprint devices + service as #1MillionProject pilot program kicks off @sdschools!! https://t.co/xzVxdmWEBp',
#  'Appreciate our customers. @EmelyMartinez09 @jordan_stupar @Lori_AnneHill @Chidalgosaez @Sprint4FL @sprint @GrantCardone @sprintsback https://t.co/AMExrw7Btf',
#  'Excited for @sdschools 1Million Project with @sprint Every student deserves to be fully connected https://t.co/GUUsG4Dr16 #DigitalDivide https://t.co/rczCBRrAjP',
#  "Thank y'all for the birthday love. 45 is pretty weird. Pacing well. Marathon not a sprint.",
#  '3.5% of 324M = 11.3M people in united, sustained effort. Again: this is a marathon, not a sprint. Money, marches, calls to reps, noise!! 💙 https://t.co/Ptxe1k468L',
#  '#CarpeDiem in 2017! Thanks to #Sprint, it’s easy to seize the day – get $100 for each new line. https://t.co/8bZdiOn12E https://t.co/tS1mrQnzrJ',
#  'Super Bowl Prep - AT&amp;T, Sprint &amp; Verizon increased their network capacities w/ temp cell towers in Houston https://t.co/Dqy0vCgCm1',
#  'Me and Heather having fun and discussing how Sprint can win!! @Buggalicious1 @SPG_JB https://t.co/VZg3I3VVZF',
#  '"The president understands this is a marathon, not a sprint" - he can barely make it to 5PM without getting tired https://t.co/wb98Cndpkh',
#  "The sprint worker hooked me up duuuude I didn't have to pay as much as I thought to get the 7   yous a real one Fabiola 🙌",
#  'To be clear, we saw some great potential in the no sprint while reloading test on the PTS, but based on many factors, now was not the time.',
#  'switching to Sprint at the Navigation Street Party @SprintCentralTX  #UnlimitedBowl https://t.co/6Yv6I5hpn3',
#  "Thanks for sucking all day @sprint, finally got some wifi and I'm back to having a phone. WHERE IS MY LTE DANG IT?",
#  'Congrats to @sprint &amp; BioTelemetry, Inc. on the 2017 #IoTEvolution Business Impact Award!  https://t.co/N1TsrDZjlz',
#  'Josh at Costco 369 helping these 3 customers join the sprint family. #noonewalks #costcompForTheWin @kc_jamie_wilson @TimMiller44 https://t.co/bEdz9dmGup',
#  "Let's do a 30 minute sprint at :00! Good luck!",
#  'Good things happening early at Hillsdale: PRs in sprint/hurdle heats for D. Ettinger, S. Ettinger, K. Patton; big SB for Hannah in weight!',
#  'A predicted sprint finish today for Stage 3, who do you think will win? #SunTour @TeamSky @teamjltcondor @IsoWheySwissWel @CyclingAus',
#  'Brad Sweet with his new colours https://t.co/Vy9EFEo44k',
#  'Tim Schaffer and DR Racing ready for 2017. https://t.co/yqgULldJjE',
#  'Deal: Sprint Offering Buy One, Get One Free on the LG V20 – 2/3/17 https://t.co/AzQPeh09v6 https://t.co/3ljdYCwLNA',
#  '@UncleLouie @sprint Truth Hurts!  Lol',
#  'Think your organization could benefit from a structured design sprint? Tune in 2/8 &amp; see how to get execs on board: https://t.co/Swyu870ndb https://t.co/sYiEwQtkUI',
#  'definitely bouta get a 7 cause that camera silly asf 😩 i need to call sprint',
#  'Another road season approaches. Time to kit out the new Commissaires courtesy of @oakley73 at Sprint Design Inc with this on time delivery https://t.co/RhFbrxsL7H',
#  'Come see us and save money on your phone bill! 740 W. Main in Norman! @sprint',
#  'Proud Sprint gives Brockton high students free smartphones, tablets https://t.co/jIOyJLmgPo via @BostonGlobe',
#  'Sweet deal for #ValentinesDay @Sprint: 2 lines w/ #unlimited data, talk &amp; text for $90 + Buy 1 LG V20, get 1 FREE! https://t.co/2bM3sOTrqx https://t.co/SHPe1RIArC',
#  'Buick has an attention-grabbing Super Bowl ad. So does Budweiser. And Sprint. Watch them all, and more, here. https://t.co/1zaM4bynUL https://t.co/P1lTAcl8ld',
#  'Meet Sean Salisbury &amp; Ray Childress @ our Hwy 59N @Sprint store in Humble, TX @ 4PM. #SB51 #UnlimitedBowl @marceloclaure @JGSprintWest https://t.co/xY5tNTXBIK',
#  'Get ready for a bunch sprint. “Stage 3 to Mitchelton Winery is for the pure fast men."  Stage finish: 2.30pm (local) / 3.30am (GMT) #SunTour https://t.co/baQH2XG3Jm',
#  'Great show this morning @johngranato @The_Raheel .  Looking sporty in your #Sprint shirts! #UnlimitedBowl https://t.co/SlUYKn3fjP',
#  'Remember that time Wise Dan ran in the BC Sprint? Was only beaten a few lengths by this champ... https://t.co/9wEEuhj13n',
#  "Remember, this is a marathon, not a sprint. We've got to stay fueled &amp; energized. https://t.co/i3vifMHYxQ",
#  "Great Gift cards on Sprint phones at Sam's Clubs!!! @markjacksonKC5 @krisspragg https://t.co/jEFyQaIS1q",
#  '[BREAKING] The deadline for our Innovation Sprint: AM Case Study Challenge has been EXTENDED to Monday February 20th https://t.co/uEJmTylz1r',
#  'Kicking off the #ESPN Street Party! Stop by our @Sprint booth! #SB51 #UnlimitedBowl @marceloclaure @JGSprintWest https://t.co/utc2lTSkAR',
#  'Sales Ops Review for #MundoWireless. Good things to come for #2017. #GainingCommitments @Kim_Marceco @MW_Marceco @TimJamaal @mary_sprint https://t.co/rVOp1zQpMq',
#  '@LFRSLutterworth  @Kris_Impact  Back to back classes tonight, Cardio run/sprint/walk+tyre hit followed by fitness class #teamimpact #focus https://t.co/EHYkvVMjnk',
#  'seeing the football boys sprint to 6th period makes me laugh every time',
#  'Love #lgv20 and bogo!!! @SellWithLG @LGUSAMobile @sprint @Sprint4NYC @jskinn02 @bruce_sokol',
#  'Come see me &amp; the @Sprint_KCPlaza table at @HRBlock on Blue Parkway in KC, MO &amp; save on wireless while you prepare your taxes! #TaxSeason',
#  "The third annual Citizen's First Shamrock Sprint is a FREE kids run that takes place in Franklin Kentucky for... https://t.co/3M7tseiQs3",
#  'Great #Sprint app to help secure personal data &amp; privacy when using public #WiFi 📱💻 https://t.co/TAIPTgALz5',
#  'Yes, but Tidal is more a konami than a tsunami, @evankirstel, @sprint and @motherboard...  $S #netneutrality #zerorating https://t.co/pC2eZzPgzL',
#  "why does sprint LTE service suck but their unlimited data plan is better than anyone else's .",
#  "Week one of the #Resistance was very outward focused, but week two has been, by necessity, about self-care. It's a marathon, not a sprint.",
#  'Demetrius just helped switch over a very happy Bette to Sprint @ the 8th Annual Northdale Public Safety Fair. @marshalltilley  @cannlee17 https://t.co/dIy53WT3Lt',
#  '@ChuckitUK We @DuncanPickles like to keep fit with resistance sprint relays #ChuckItFit https://t.co/GkvX9sc6n4',
#  "And that's a wrap! Thank you so much @KyoceraMobile @sprint @Sprint4Arizona @toddephx for the continued support! See you next year! https://t.co/XhOvsqssQt",
#  'Great design sprint experience so far...! #NextGenMobility @netimpact @Toyota https://t.co/aA7gnvGLjK',
#  'Unreal smooth gameplay by @EASPORTSFIFA (and yes that is the game controlling my players and making them sprint away) https://t.co/mkbwgRB4xR',
#  'The energy from everyone @Sprint is awesome!! I’m tremendously proud of our accomplishments &amp; ready to #ACCELERATE our progress in 2017! https://t.co/XaV1fM7MP3',
#  'Thank you @Sprint and @MikeArbide for supporting our SDPBC Academic Challenge! #GrowingStrong https://t.co/Le9QGtcujd',
#  'Well done @JonAntoine ! Another sprint up charts to #3 @officialcharts #Classical with #Believe Well it is best album ever!! https://t.co/qQzuHn8nRp',
#  'Absolute Value Sprint game 6th grade math @BellevueHS @jeff_recker https://t.co/mdPF0PCTjC',
#  "#Bitcoin's growth is a marathon, not a sprint. #Cryptocurrency",
#  'Thank you @codesyntax for sponsoring the #Plone #BeethovenSprint and sending us @erralin to Bonn in March. https://t.co/2w7lM11Hss #sprint',
#  'On why Trump\'s approval ratings are so low, @PressSec responds: "The President understands this is a marathon, not a sprint." https://t.co/zDuq11Qgd9',
#  "@UKRunChat so people, what's the strongest part of your run? Sprint finish? Fast start? Consistent plod?",
#  'Why Sprint buying a healthy chunk of Tidal has net neutrality advocates shaken up https://t.co/aXG9Id1RqE https://t.co/HhTYAfi1qD',
#  "I wish sprint wasn't so shitty",
#  '.@PressSec on Trump\'s approval ratings: "It\'s a marathon, not a sprint."',
#  'Spicer on Trump\'s approval rating: "The president understands this is a marathon, not a sprint." Watch live: https://t.co/TqTWHjUzCR',
#  '.@PressSec on president’s low approval ratings: "The president understands this is a marathon not a sprint.” He predicts poll #s will rise',
#  'Complaining there were not many #triathlons in August? Well @Caderman893 listened!! https://t.co/xDKNYm7eFA #uktrichat sprint+middle 5thAug https://t.co/MMsnV6U0Ed',
#  '"Can u thank the person who decided to put auto sprint in Titan? Being a disabled gamer this makes the game much better!” - @SpeediRare',
#  "Take care of yourself: this isn't a sprint, it's not even a marathon. It's a relay. #buildthemovement #FridayFeeling https://t.co/lRt1JLj9va",
#  "#SpicerFacts Crediting Trump with Sprint's job roll-out that was announced before Trump even had conversation with them https://t.co/ompmRtOD7D",
#  "Today's Town Hall was very encouraging!! @marceloclaure we are doing it Boss!! We will continue to fight every day! #Sprint https://t.co/oQk6YkDm3N",
#  'GoodBye sprint, Hello TMO!!! 66th St all about the Great Customer Experience!#FeeFace @cjgreentx @PeterRuvelas @JohnLegere @JonFreier https://t.co/Huc1QcDMQc',
#  'Glad to attend our @Sprint Employee Town Hall today. Heard updates on our transformational journey. Great things coming! #Accelerate https://t.co/yaaQleUHyB',
#  '#SprintNorthridge gaining knowledge to ensure our CL customers get the best deals with Sprint! @Margaux_gokings @Tigre335 @newinca2k8955 https://t.co/izPRnmvrRL',
#  'How fast can you devour a dozen donuts while in full sprint? Welcome to the Krispy Kreme Challenge https://t.co/a47j8AhaEr',
#  "Visit Sprint Foundation's #1MillionProject https://t.co/Fixr53aG2E for grants to close digital divide Deadline March 31, 2017 https://t.co/oUcS1LKtST",
#  'Amazing updates from our leader @marceloclaure today!So proud to be a part of this team-proud of what we are doing at Sprint!@mark_nachman',
#  'I started printing the shipping labels for the Sprint Training Outing with @The7LineArmy!! 🍻 Cheers to the new season! #LGM2017 ⚾️💙',
#  'The passion. The heart. The drive. Every practice free throw sprint late night early morning HOW BAD DO YOU WANT IT?! https://t.co/KGyBVaubVj',
#  "@Newsletter_Pro @jonbuscall So true! It's a marathon, not a sprint!",
#  'goals for our sprint this weekend: get more people testing elmsln, continue angular2 transformation, expand angular based APIs, data viz',
#  'Once GB W8+ and M8+ Sprint Champions have been decided in any way set up by @BritishRowing then happy to see them @RowingCL https://t.co/yyVYcpeymN',
#  "Sprint gives free wifi hotspots to low-income #KC high schoolers who don't have internet access at home: https://t.co/ZHgaPnnfrb",
#  'Buy one LG V20 &amp; get one for your Valentine FREE. Love is 4ever but this offer ends 3/9, so get yours now at any of our Sprint stores! https://t.co/5pXMHTZ1NR',
#  "At Olympic Training Center. Dr. Ralph Mann America's greatest sprint biomechanic expert. Wow! https://t.co/tZahxSiqST",
#  "It's BACK but only for a limited time! Switch and SAVE! #TheSwitchisReal https://t.co/vmMFcwXBA1",
#  'Travis Johnson with @espn here at the Pasadena Sprint store! How awesome is that??? #Houston #Texans #Sprint #SuperBowl #UnlimitedBowl https://t.co/HeSTMOSDhr',
#  "@ActualEPAFacts Agree 100%. It's not a sprint and not a marathon, but a triathlon we're beginning. Need considerable planning to survive.",
#  'Join @Sprint &amp; @espn975 all week for player appearances throughout the #Houston area. #UnlimitedBowl @JGSprintWest @sprint @marceloclaure https://t.co/ehLyQrT7zo',
#  'Not just drinking the @sprint kool-aid, our new ad campaign makes me laugh hard. https://t.co/Hp3nFP8LNb',
#  "That's the sprint champ ✊🏽 https://t.co/wluktGkeeU",
#  'Blogged: A Pleiades Documentation "Sprint": Let\'s club together to update and improve the help section and ... https://t.co/3sB4bgQqmT',
#  'Deal: Sprint Offering Buy One, Get One Free on the LG V20 – 2/3/17 https://t.co/ODldBY3Hb3 #Android #news #Google #Smartphones https://t.co/RRjpboiRJv',
#  'I really enjoy my quarterly Town Hall meetings w/ partners!! Excited to discuss how @Sprint’s #turnaround plan is turning the corner in Q3! https://t.co/vCGT7koyHK',
#  "Sorry @Verizon you can't stop @sprint! https://t.co/urfo9K0gKD",
#  '@marceloclaure @probertson2533 @SprintCentralTX @sprint @verizon this is great. Yellow Gladiators! Poor Lowell 😂',
#  'Kevin &amp; Demetrius explaining the benefits of switching to Sprint @ the 8th annual Northdale Public Safety Fair. @marshalltilley  @cannlee17 https://t.co/uqYlVvQ4TI',
#  '#NowHiring #Sprint Business Sales #Intern - #Chandler #AZ. Are you ready to put your education to work? https://t.co/ndHv93s0WZ https://t.co/lwU1EtS7WF',
#  '#VCV2017 3rd stage of @VueltaCV: @MagnusCort🇩🇰 (@OricaScott) wins the sprint over @BouhanniNacer🇫🇷 &amp; @BryanCoquard🇫🇷 https://t.co/QGwf2oJaIv',
#  'FeatureMap 2.11.2 to be deployed this weekend, will fix Excel import and let you import @JIRA projects with no sprint support',
#  'Sprint finish stage 3 @VueltaCV: winner Magnus Cort Nielsen (ORS), 10th place for @v_kuznetsov89 #TeamKatushaAlpecin #raceasafamily https://t.co/ejI5JIYnW6',
#  ...]

# %%
before_result = before_df.groupby(['comp_score', 'Company_Name', 'Year'])['Text'].count().reset_index()
after_result = after_df.groupby(['comp_score', 'Company_Name', 'Year'])['Text'].count().reset_index()
after_superbowl_result = after_superbowl_df.groupby(['comp_score', 'Company_Name', 'Year'])['Text'].count().reset_index()

# %% [markdown]
# ### Analysis on Sample Dataset

# %%
before_result[before_result['Company_Name'].isin(['T-Mobile'])].reset_index(drop=True)
# Out:
#    comp_score Company_Name  Year  Text
# 0         neg     T-Mobile  2015    61
# 1         neg     T-Mobile  2016    39
# 2         neg     T-Mobile  2017    67
# 3         neg     T-Mobile  2018    39
# 4         neg     T-Mobile  2019    17
# 5         neg     T-Mobile  2021    85
# 6         neg     T-Mobile  2022    65
# 7         neu     T-Mobile  2015   101
# 8         neu     T-Mobile  2016   103
# 9         neu     T-Mobile  2017   192
# 10        neu     T-Mobile  2018    60
# 11        neu     T-Mobile  2019    45
# 12        neu     T-Mobile  2021    76
# 13        neu     T-Mobile  2022    64
# 14        pos     T-Mobile  2015   176
# 15        pos     T-Mobile  2016   136
# 16        pos     T-Mobile  2017   368
# 17        pos     T-Mobile  2018   143
# 18        pos     T-Mobile  2019   147
# 19        pos     T-Mobile  2021   233
# 20        pos     T-Mobile  2022   121

# %%
before_df[before_df['Company_Name'].isin(['T-Mobile'])].groupby(['Year', 'Company_Name'])['Text'].count().reset_index().rename({'Text': 'Total_Tweets'}, axis = 1)
# Out:
#    Year Company_Name  Total_Tweets
# 0  2015     T-Mobile           338
# 1  2016     T-Mobile           278
# 2  2017     T-Mobile           627
# 3  2018     T-Mobile           242
# 4  2019     T-Mobile           209
# 5  2021     T-Mobile           394
# 6  2022     T-Mobile           250

# %%
join_before = pd.merge(before_df[before_df['Company_Name'].isin(['T-Mobile'])].groupby(['Year', 'Company_Name'])['Text'].count().reset_index().rename({'Text': 'Total_Tweets'}, axis = 1), 
        before_result[before_result['Company_Name'].isin(['T-Mobile'])].reset_index(drop=True),  
        how='left', 
        left_on=['Company_Name','Year'], 
        right_on = ['Company_Name','Year'])

join_before.head()
# Out:
#    Year Company_Name  Total_Tweets comp_score  Text
# 0  2015     T-Mobile           338        neg    61
# 1  2015     T-Mobile           338        neu   101
# 2  2015     T-Mobile           338        pos   176
# 3  2016     T-Mobile           278        neg    39
# 4  2016     T-Mobile           278        neu   103

# %%
join_before['perc'] = join_before['Text']/join_before['Total_Tweets']
join_before.head()
# Out:
#    Year Company_Name  Total_Tweets comp_score  Text      perc
# 0  2015     T-Mobile           338        neg    61  0.180473
# 1  2015     T-Mobile           338        neu   101  0.298817
# 2  2015     T-Mobile           338        pos   176  0.520710
# 3  2016     T-Mobile           278        neg    39  0.140288
# 4  2016     T-Mobile           278        neu   103  0.370504

# %%
after_result[after_result['Company_Name'].isin(['T-Mobile'])]
# Out:
#    comp_score Company_Name  Year  Text
# 0         neg     T-Mobile  2015    69
# 1         neg     T-Mobile  2016   115
# 2         neg     T-Mobile  2017   147
# 3         neg     T-Mobile  2018   209
# 4         neg     T-Mobile  2019    98
# 5         neg     T-Mobile  2021    76
# 6         neg     T-Mobile  2022    99
# 35        neu     T-Mobile  2015    86
# 36        neu     T-Mobile  2016   175
# 37        neu     T-Mobile  2017   193
# 38        neu     T-Mobile  2018   121
# 39        neu     T-Mobile  2019   161
# 40        neu     T-Mobile  2021   158
# 41        neu     T-Mobile  2022   113
# 70        pos     T-Mobile  2015   595
# 71        pos     T-Mobile  2016   460
# 72        pos     T-Mobile  2017   410
# 73        pos     T-Mobile  2018   420
# 74        pos     T-Mobile  2019   491
# 75        pos     T-Mobile  2021   401
# 76        pos     T-Mobile  2022   244

# %%
after_df[after_df['Company_Name'].isin(['T-Mobile'])].groupby(['Year', 'Company_Name'])['Text'].count().reset_index().rename({'Text': 'Total_Tweets'}, axis = 1)
# Out:
#    Year Company_Name  Total_Tweets
# 0  2015     T-Mobile           750
# 1  2016     T-Mobile           750
# 2  2017     T-Mobile           750
# 3  2018     T-Mobile           750
# 4  2019     T-Mobile           750
# 5  2021     T-Mobile           635
# 6  2022     T-Mobile           456

# %%
join_after = pd.merge(after_df[after_df['Company_Name'].isin(['T-Mobile'])].groupby(['Year', 'Company_Name'])['Text'].count().reset_index().rename({'Text': 'Total_Tweets'}, axis = 1), 
        after_result[after_result['Company_Name'].isin(['T-Mobile'])].reset_index(drop=True),  
        how='left', 
        left_on=['Company_Name','Year'], 
        right_on = ['Company_Name','Year'])

join_after['perc'] = join_after['Text']/join_after['Total_Tweets']
join_after.head()
# Out:
#    Year Company_Name  Total_Tweets comp_score  Text      perc
# 0  2015     T-Mobile           750        neg    69  0.092000
# 1  2015     T-Mobile           750        neu    86  0.114667
# 2  2015     T-Mobile           750        pos   595  0.793333
# 3  2016     T-Mobile           750        neg   115  0.153333
# 4  2016     T-Mobile           750        neu   175  0.233333

# %%
join_after
# Out:
#     Year Company_Name  Total_Tweets comp_score  Text      perc
# 0   2015     T-Mobile           750        neg    69  0.092000
# 1   2015     T-Mobile           750        neu    86  0.114667
# 2   2015     T-Mobile           750        pos   595  0.793333
# 3   2016     T-Mobile           750        neg   115  0.153333
# 4   2016     T-Mobile           750        neu   175  0.233333
# 5   2016     T-Mobile           750        pos   460  0.613333
# 6   2017     T-Mobile           750        neg   147  0.196000
# 7   2017     T-Mobile           750        neu   193  0.257333
# 8   2017     T-Mobile           750        pos   410  0.546667
# 9   2018     T-Mobile           750        neg   209  0.278667
# 10  2018     T-Mobile           750        neu   121  0.161333
# 11  2018     T-Mobile           750        pos   420  0.560000
# 12  2019     T-Mobile           750        neg    98  0.130667
# 13  2019     T-Mobile           750        neu   161  0.214667
# 14  2019     T-Mobile           750        pos   491  0.654667
# 15  2021     T-Mobile           635        neg    76  0.119685
# 16  2021     T-Mobile           635        neu   158  0.248819
# 17  2021     T-Mobile           635        pos   401  0.631496
# 18  2022     T-Mobile           456        neg    99  0.217105
# 19  2022     T-Mobile           456        neu   113  0.247807
# 20  2022     T-Mobile           456        pos   244  0.535088

# %%
join_after = join_after.rename({'perc': 'after_perc'}, axis = 1)
join_after.head()
# Out:
#    Year Company_Name  Total_Tweets comp_score  Text  after_perc
# 0  2015     T-Mobile           750        neg    69    0.092000
# 1  2015     T-Mobile           750        neu    86    0.114667
# 2  2015     T-Mobile           750        pos   595    0.793333
# 3  2016     T-Mobile           750        neg   115    0.153333
# 4  2016     T-Mobile           750        neu   175    0.233333

# %%
join_before = join_before.rename({'perc': 'before_perc'}, axis = 1)
join_before.head()
# Out:
#    Year Company_Name  Total_Tweets comp_score  Text  before_perc
# 0  2015     T-Mobile           338        neg    61     0.180473
# 1  2015     T-Mobile           338        neu   101     0.298817
# 2  2015     T-Mobile           338        pos   176     0.520710
# 3  2016     T-Mobile           278        neg    39     0.140288
# 4  2016     T-Mobile           278        neu   103     0.370504

# %%
join_final = pd.merge(join_before, join_after,   
        how='left', 
        left_on=['Company_Name','Year', 'comp_score'], 
        right_on = ['Company_Name','Year', 'comp_score'])

join_final.head()
# Out:
#    Year Company_Name  Total_Tweets_x comp_score  Text_x  before_perc  \
# 0  2015     T-Mobile             338        neg      61     0.180473
# 1  2015     T-Mobile             338        neu     101     0.298817
# 2  2015     T-Mobile             338        pos     176     0.520710
# 3  2016     T-Mobile             278        neg      39     0.140288
# 4  2016     T-Mobile             278        neu     103     0.370504
#
#    Total_Tweets_y  Text_y  after_perc
# 0             750      69    0.092000
# 1             750      86    0.114667
# 2             750     595    0.793333
# 3             750     115    0.153333
# 4             750     175    0.233333

# %%
def categorize(row):
    if row['after_perc'] > row['before_perc']:
        return 'increase'
    return 'decrease'

# %%
join_final['result'] = join_final.apply(lambda row: categorize(row), axis = 1)
join_final.head()
# Out:
#    Year Company_Name  Total_Tweets_x comp_score  Text_x  before_perc  \
# 0  2015     T-Mobile             338        neg      61     0.180473
# 1  2015     T-Mobile             338        neu     101     0.298817
# 2  2015     T-Mobile             338        pos     176     0.520710
# 3  2016     T-Mobile             278        neg      39     0.140288
# 4  2016     T-Mobile             278        neu     103     0.370504
#
#    Total_Tweets_y  Text_y  after_perc    result
# 0             750      69    0.092000  decrease
# 1             750      86    0.114667  decrease
# 2             750     595    0.793333  increase
# 3             750     115    0.153333  increase
# 4             750     175    0.233333  decrease

# %% [markdown]
# -----

# %% [markdown]
# ### Analysis on all datasets

# %%
join_before = pd.merge(before_df.groupby(['Year', 'Company_Name'])['Text'].count().reset_index().rename({'Text': 'Total_Tweets'}, axis = 1), 
        before_result.reset_index(drop=True),  
        how='left', 
        left_on=['Company_Name','Year'], 
        right_on = ['Company_Name','Year'])

join_before['perc'] = join_before['Text']/join_before['Total_Tweets']

join_after = pd.merge(after_df.groupby(['Year', 'Company_Name'])['Text'].count().reset_index().rename({'Text': 'Total_Tweets'}, axis = 1), 
        after_result.reset_index(drop=True),  
        how='left', 
        left_on=['Company_Name','Year'], 
        right_on = ['Company_Name','Year'])

join_after['perc'] = join_after['Text']/join_after['Total_Tweets']


join_after = join_after.rename({'perc': 'after_perc'}, axis = 1)
join_before = join_before.rename({'perc': 'before_perc'}, axis = 1)

join_final = pd.merge(join_before, join_after,   
        how='left', 
        left_on=['Company_Name','Year', 'comp_score'], 
        right_on = ['Company_Name','Year', 'comp_score'])
        
def categorize(row):
    if row['after_perc'] > row['before_perc']:
        return 'increase'
    return 'decrease'

join_final['result'] = join_final.apply(lambda row: categorize(row), axis = 1)

join_final.head()
# Out:
#    Year Company_Name  Total_Tweets_x comp_score  Text_x  before_perc  \
# 0  2015     T-Mobile             338        neg      61     0.180473
# 1  2015     T-Mobile             338        neu     101     0.298817
# 2  2015     T-Mobile             338        pos     176     0.520710
# 3  2015       sprint             750        neg     172     0.229333
# 4  2015       sprint             750        neu     272     0.362667
#
#    Total_Tweets_y  Text_y  after_perc    result
# 0             750      69    0.092000  decrease
# 1             750      86    0.114667  decrease
# 2             750     595    0.793333  increase
# 3             750     188    0.250667  increase
# 4             750     289    0.385333  increase

# %%
join_final
# Out:
#      Year  Company_Name  Total_Tweets_x comp_score  Text_x  before_perc  \
# 0    2015      T-Mobile             338        neg      61     0.180473
# 1    2015      T-Mobile             338        neu     101     0.298817
# 2    2015      T-Mobile             338        pos     176     0.520710
# 3    2015        sprint             750        neg     172     0.229333
# 4    2015        sprint             750        neu     272     0.362667
# ..    ...           ...             ...        ...     ...          ...
# 99   2022     uber eats             322        neu      99     0.307453
# 100  2022     uber eats             322        pos     124     0.385093
# 101  2022  weather tech              19        neg       4     0.210526
# 102  2022  weather tech              19        neu       6     0.315789
# 103  2022  weather tech              19        pos       9     0.473684
#
#      Total_Tweets_y  Text_y  after_perc    result
# 0               750      69    0.092000  decrease
# 1               750      86    0.114667  decrease
# 2               750     595    0.793333  increase
# 3               750     188    0.250667  increase
# 4               750     289    0.385333  increase
# ..              ...     ...         ...       ...
# 99              696     207    0.297414  decrease
# 100             696     311    0.446839  increase
# 101              43       5    0.116279  decrease
# 102              43      13    0.302326  decrease
# 103              43      25    0.581395  increase
#
# [104 rows x 10 columns]
